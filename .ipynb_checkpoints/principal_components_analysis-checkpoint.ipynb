# %%
# import modules
import pandas as pd
import glob
import re
import matplotlib.pyplot as plt

# %% [markdown]
# # Import DataFrames

# %%
# get raw data
df = pd.read_csv('dataframes/pos_df.csv')
df.head()
# Out:
#                         Sample Name    CAS9-A  CAS9-A.1    CAS9-B  CAS9-B.1  \
# 0  Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  167.0000  143.0000  125.0000  132.0000
# 1  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)   53.2158   52.8015   47.4908   76.2783
# 2  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  167.8122  131.3388  220.0689  128.3439
# 3   Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   54.0000   47.0000   39.0000   44.0000
# 4  Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  391.2240  326.4641  444.7720  385.3202
#
#       CAV_A   CAV_A.1     CAV_B   CAV_B.1   CAVIN_A  ...   SPTLC_B  SPTLC_B.1  \
# 0  171.6091  182.9007  120.0000  120.0000  281.3523  ...  130.0000   142.0000
# 1   27.6563   23.0569    9.0712   24.0712    0.0000  ...    0.0000     2.1176
# 2  342.9760  331.4596  268.9979  289.4925  295.0869  ...  290.0353   223.3067
# 3   74.0000   64.0000   84.5341   88.7361   70.0000  ...   44.0000    37.0000
# 4  175.0126  296.5953  238.6997  214.9442  215.1018  ...  309.7805   272.9937
#
#      UGCG-A  UGCG-A.1    UGCG-B  UGCG-B.1      WT_A    WT_A.1      WT_B  \
# 0   68.0529   46.4729   88.0000   91.0000  229.5233  278.1255  206.0000
# 1   47.2560   62.7063   11.1856    0.0000   10.8768    6.0672    0.0000
# 2  187.9922  219.2679  231.3212  219.2373  329.9421  313.2847  251.0406
# 3   48.6404   51.9843   38.9995   52.0000   62.0000   57.0000   51.0000
# 4  373.2111  292.2522  348.9607  348.3176  304.3199  271.4133  303.6544
#
#      WT_B.1
# 0  182.0000
# 1   34.4747
# 2  226.8066
# 3   40.0000
# 4  253.3654
#
# [5 rows x 43 columns]

# %%
# get lipid metadata
df_meta = pd.read_csv('dataframes/pos_lipids_df_meta.csv')
df_meta.sample(5)
# Out:
#                                            Sample Name Head Group  \
# 2909                             PG O-38:3 (-PG (NH4))       PG O
# 4138                   MADAG 52:9+NH4 (-FA 16:2 (NH4))      MADAG
# 2521                  Hex3Cer 48:0;3 (LCB 18:0;2-2H2O)    Hex3Cer
# 2461  Hex3Cer 26:0;4 (LCB 18:1;2-2H2O,LCB 18:0;3-3H2O)    Hex3Cer
# 4580                   MADAG 50:7+NH4 (-FA 16:1 (NH4))      MADAG
#
#       Acyl Chain Length  Unsaturation
# 2909                 38             3
# 4138                 52             9
# 2521                 48             0
# 2461                 26             0
# 4580                 50             7

# %%
# get experiment metadata
df_exps = pd.read_csv('dataframes/pos_exps_df_meta.csv')
df_exps.sample(5)
# Out:
#         sample   protein
# 26     Flot2-B     Flot2
# 1     CAS9-A.1      CAS9
# 36      UGCG-B      UGCG
# 16  CERS2-1g_A  CERS2-1g
# 22     CERS5-B     CERS5

# %% [markdown]
# # Principal Components Analysis (Transposed)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# drop the blank columns and transpose dataframe
samples = df["Sample Name"]
df_dropped = df.drop(["Sample Name", "RAJU-Blank", "RAJU-Blank.1"], axis=1)

df_dropped = df_dropped.T
exps = df_dropped.index

x = df_dropped.values

# for each column, standardize the values
x = StandardScaler().fit_transform(x)

# check random column for standardization (mean=0, standard deviation=1)
x.shape, np.mean(x[:,20]), np.std(x[:,20])
# Out:
# ((40, 5479), 4.4408920985006264e-17, 1.0)

# %%
# create dataframe with standardized values
df_standardized = pd.DataFrame(x, columns=samples)
df_standardized = df_standardized.set_index(exps)
df_standardized.head(10)
# Out:
# Sample Name  Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                              -0.119632
# CAS9-A.1                            -0.553561
# CAS9-B                              -0.879008
# CAS9-B.1                            -0.752445
# CAV_A                               -0.036297
# CAV_A.1                              0.167859
# CAV_B                               -0.969410
# CAV_B.1                             -0.969410
# CAVIN_A                              1.947901
# CAVIN_A.1                            0.193994
#
# Sample Name  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                               1.767019
# CAS9-A.1                             1.746037
# CAS9-B                               1.477073
# CAS9-B.1                             2.935033
# CAV_A                                0.472543
# CAV_A.1                              0.239604
# CAV_B                               -0.468710
# CAV_B.1                              0.290974
# CAVIN_A                             -0.928126
# CAVIN_A.1                           -0.226649
#
# Sample Name  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                              -1.638565
# CAS9-A.1                            -2.330926
# CAS9-B                              -0.646596
# CAS9-B.1                            -2.387777
# CAV_A                                1.686503
# CAV_A.1                              1.467892
# CAV_B                                0.282205
# CAV_B.1                              0.671246
# CAVIN_A                              0.777443
# CAVIN_A.1                           -0.553325
#
# Sample Name  Hex2Cer 26:2;2 (LCB 18:0;2-H2O)  \
# CAS9-A                              0.206113
# CAS9-A.1                           -0.207008
# CAS9-B                             -0.679147
# CAS9-B.1                           -0.384060
# CAV_A                               1.386459
# CAV_A.1                             0.796286
# CAV_B                               2.008153
# CAV_B.1                             2.256143
# CAVIN_A                             1.150389
# CAVIN_A.1                           0.029061
#
# Sample Name  Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                               1.929826
# CAS9-A.1                             1.015202
# CAS9-B                               2.686101
# CAS9-B.1                             1.846445
# CAV_A                               -1.123793
# CAV_A.1                              0.593356
# CAV_B                               -0.224321
# CAV_B.1                             -0.559827
# CAVIN_A                             -0.557601
# CAVIN_A.1                           -0.563991
#
# Sample Name  Hex2Cer 26:0;2 (LCB 18:0;2-H2O)  Hex2Cer 26:4;3 (LCB 18:0;2-H2O)  \
# CAS9-A                              0.169306                         2.227004
# CAS9-A.1                            0.228176                        -0.659004
# CAS9-B                              2.670966                        -0.659004
# CAS9-B.1                            0.127014                         2.050161
# CAV_A                               0.761665                        -0.659004
# CAV_A.1                             0.310385                        -0.659004
# CAV_B                              -0.329849                         2.049686
# CAV_B.1                             1.425733                         0.806763
# CAVIN_A                             0.745717                        -0.659004
# CAVIN_A.1                          -0.949952                         0.258598
#
# Sample Name  Hex2Cer 26:4;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# CAS9-A                                              0.471287
# CAS9-A.1                                           -0.757276
# CAS9-B                                              0.207133
# CAS9-B.1                                           -0.757276
# CAV_A                                              -0.757276
# CAV_A.1                                            -0.757276
# CAV_B                                              -0.757276
# CAV_B.1                                            -0.757276
# CAVIN_A                                            -0.757276
# CAVIN_A.1                                           1.358562
#
# Sample Name  Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# CAS9-A                                              0.400821
# CAS9-A.1                                           -0.763288
# CAS9-B                                              1.172339
# CAS9-B.1                                            1.298701
# CAV_A                                               1.040952
# CAV_A.1                                             0.783203
# CAV_B                                              -0.763288
# CAV_B.1                                            -0.763288
# CAVIN_A                                             1.040952
# CAVIN_A.1                                           1.291696
#
# Sample Name  Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  ...  \
# CAS9-A                                             -0.494894  ...
# CAS9-A.1                                           -0.494894  ...
# CAS9-B                                             -0.494894  ...
# CAS9-B.1                                            2.624122  ...
# CAV_A                                              -0.494894  ...
# CAV_A.1                                             1.409335  ...
# CAV_B                                              -0.494894  ...
# CAV_B.1                                            -0.494894  ...
# CAVIN_A                                             0.929145  ...
# CAVIN_A.1                                          -0.494894  ...
#
# Sample Name  DAG 35:0+NH4 (-FA 17:0 (NH4))  DAG 38:4+NH4 (-FA 18:1 (NH4))  \
# CAS9-A                           -0.482176                      -0.398903
# CAS9-A.1                         -0.482176                      -0.398903
# CAS9-B                           -0.482176                      -0.398903
# CAS9-B.1                         -0.482176                      -0.398903
# CAV_A                             3.019255                       2.518582
# CAV_A.1                           2.669112                       3.887279
# CAV_B                             1.531147                       2.266454
# CAV_B.1                           1.239361                       1.582106
# CAVIN_A                          -0.482176                      -0.398903
# CAVIN_A.1                        -0.482176                      -0.398903
#
# Sample Name  DAG 38:4+NH4 (-FA 20:3 (NH4))  DAG 38:4+NH4 (-FA 20:4 (NH4))  \
# CAS9-A                           -0.370975                      -0.350245
# CAS9-A.1                         -0.370975                      -0.350245
# CAS9-B                           -0.370975                      -0.350245
# CAS9-B.1                         -0.370975                      -0.350245
# CAV_A                             2.754141                       3.625649
# CAV_A.1                           2.924216                      -0.350245
# CAV_B                             2.860438                       2.964777
# CAV_B.1                           2.924216                       3.316531
# CAVIN_A                          -0.370975                      -0.350245
# CAVIN_A.1                        -0.370975                      -0.350245
#
# Sample Name  MADAG 38:2+NH4 (-FA 13:0 (NH4))  DAG 38:2+NH4 (-FA 16:1 (NH4))  \
# CAS9-A                             -0.484760                      -0.600253
# CAS9-A.1                           -0.484760                      -0.600253
# CAS9-B                             -0.484760                      -0.600253
# CAS9-B.1                           -0.484760                      -0.600253
# CAV_A                               1.846327                       0.151630
# CAV_A.1                            -0.484760                       0.452383
# CAV_B                               1.740368                       2.106525
# CAV_B.1                             1.263555                       2.557654
# CAVIN_A                            -0.484760                      -0.600253
# CAVIN_A.1                           1.210576                       1.003763
#
# Sample Name  MADAG 38:2+NH4 (-FA 16:2 (NH4))  DAG 38:2+NH4 (-FA 18:0 (NH4))  \
# CAS9-A                             -0.318859                      -0.618937
# CAS9-A.1                           -0.318859                      -0.618937
# CAS9-B                             -0.318859                      -0.618937
# CAS9-B.1                           -0.318859                      -0.618937
# CAV_A                               2.785081                      -0.100456
# CAV_A.1                             1.882117                       0.634059
# CAV_B                              -0.318859                       0.979713
# CAV_B.1                            -0.318859                       0.893300
# CAVIN_A                            -0.318859                      -0.618937
# CAVIN_A.1                           2.446470                       1.238954
#
# Sample Name  DAG 38:2+NH4 (-FA 18:1 (NH4))  MADAG 38:2+NH4 (-FA 18:2 (NH4))
# CAS9-A                           -0.593602                        -0.620205
# CAS9-A.1                         -0.593602                        -0.620205
# CAS9-B                           -0.593602                        -0.620205
# CAS9-B.1                         -0.593602                        -0.620205
# CAV_A                             0.801032                         1.933684
# CAV_A.1                           0.964328                         2.275976
# CAV_B                             0.650977                         1.529318
# CAV_B.1                           0.425893                         1.430000
# CAVIN_A                          -0.593602                        -0.620205
# CAVIN_A.1                        -0.593602                         1.779386
#
# [10 rows x 5479 columns]

# %%
# do PCA
from sklearn.decomposition import PCA
pca_lipids = PCA(n_components=10)
principal_components = pca_lipids.fit_transform(x)

# %%
# create df with pca values

# create list of columns
pcs = []
for i in range(1,11):
    pcs.append('principal component ' + str(i))
# print(pcs)

# create df
df_pca = pd.DataFrame(principal_components, columns=pcs)
df_pca["sample"] = exps
df_pca = df_pca.merge(df_exps, on='sample')
df_pca
# Out:
#     principal component 1  principal component 2  principal component 3  \
# 0               39.875468             -12.075059              44.481079
# 1               44.294816             -10.890087              43.856179
# 2               46.204060             -15.607022              41.286729
# 3               31.600266             -11.750883              27.868089
# 4              -12.779150             -11.640106              -6.150369
# 5              -15.281504             -12.530127              -6.159776
# 6              -16.213984             -37.563229              24.665301
# 7              -15.948344             -38.687423              23.574221
# 8               10.336298              14.014202              -1.827202
# 9                9.743507              12.660426              -3.868782
# 10              17.342663              -1.438128             -14.842442
# 11              18.767918              -2.154900             -12.840656
# 12             -24.781094              12.763456              -6.239589
# 13             -25.106244              14.955482              -4.168062
# 14             -22.359372              11.094345              -9.332449
# 15             -19.468487               6.641731             -10.741119
# 16             -11.136452              -7.658767             -17.569348
# 17             -13.042716              -7.251486             -17.442259
# 18             -12.798378             -15.456996              -4.840461
# 19             -11.698158             -16.121812              -0.618512
# 20              -2.515066              -4.548181             -18.569235
# 21              -3.860276              -4.952092             -19.220237
# 22              -8.694624               9.917081              -8.884586
# 23              -6.449974              10.919927              -9.652405
# 24             -26.322479              44.581367               9.226309
# 25             -37.826672              68.576438              22.155146
# 26              -3.646660              -5.698332             -16.095855
# 27              -1.287233              -5.483687             -17.801180
# 28             -25.721745             -22.960751              -6.628879
# 29             -28.994864             -27.368842              -7.067936
# 30             -19.141062             -23.799913              -7.027227
# 31             -18.448918             -24.559320              -7.134306
# 32             -16.278849              29.987790              31.787559
# 33             -19.856063              40.301489              43.841298
# 34              -4.674014             -13.341989               7.862248
# 35              -1.376459             -11.144914               9.039933
# 36              52.247802              16.429587             -26.858821
# 37              59.396120              19.775862             -27.154119
# 38              49.820049              16.886698             -21.412292
# 39              46.079874              15.178167             -19.495988
#
#     principal component 4  principal component 5  principal component 6  \
# 0              -13.215589              -9.422613              -0.500375
# 1              -13.844629             -10.503647              -1.960883
# 2              -35.784795             -20.824716              -1.104023
# 3              -23.648051              -9.127067              -5.454126
# 4               -5.930632              -9.942676              20.957294
# 5               -3.541963              -8.312622              20.414686
# 6               51.990508               1.613024              28.623284
# 7               51.147743              -0.703408              27.466567
# 8               -1.712962              -3.152884              16.409436
# 9                0.967570               0.060887              14.682828
# 10              -3.009340              -3.056758              12.423539
# 11              -3.523763              -2.597299              13.865297
# 12              -1.345864             -16.454059              -8.671769
# 13              -1.581204             -12.989796              -8.638001
# 14              -4.127896             -17.810438              -4.576162
# 15              -1.971607             -17.453895              -7.339571
# 16              -2.138490              -7.913866             -11.100034
# 17              -0.271121              -5.569273             -11.782582
# 18              21.420688             -11.005552             -18.814374
# 19              25.236249             -11.621038             -22.529811
# 20              -3.357212             -13.344406              -6.145669
# 21              -4.354711             -14.402243              -5.914075
# 22               0.734458             -10.309654              -5.599724
# 23              -0.052183             -11.924514              -4.334949
# 24              -4.664086              -4.505817              10.433133
# 25              -9.778621              -7.022869              36.710975
# 26              -6.416277             -11.364531              -8.100383
# 27              -7.875688             -10.831081              -8.732050
# 28             -23.637695              29.499262               2.455776
# 29             -33.238608              50.075525               9.419998
# 30             -25.137972              18.440318               2.758982
# 31             -26.249690              19.667282               6.643855
# 32              11.133064              26.764872             -19.810833
# 33              13.669815              32.947299             -24.972844
# 34              13.830936               7.350950             -22.519634
# 35              12.064016               8.577045             -25.275917
# 36              12.302704              12.833807               2.716670
# 37              12.213519              14.273541               9.032559
# 38              17.325995              21.262458              -0.020611
# 39              16.373383              18.800455              -1.116478
#
#     principal component 7  principal component 8  principal component 9  \
# 0                7.189998               2.476929              -0.861802
# 1               12.467121              -1.084499              62.589033
# 2               -0.980430             -13.239288             -40.054704
# 3                1.153191              -2.217087             -15.367990
# 4              -24.382637              14.264256               6.802956
# 5              -23.710407               9.944950               7.463547
# 6                4.215094             -16.437477              -5.687234
# 7                3.707638              -5.726861              -5.449245
# 8              -19.216071               6.288746               1.923072
# 9              -21.366837               6.222561               0.315742
# 10             -18.543155              18.325519              -0.027218
# 11             -19.041361              18.382803               0.228760
# 12               2.539551              -7.723559               4.241620
# 13               1.454543              -8.828291               1.189762
# 14               3.626177              -9.880825              -0.517039
# 15              -0.619632              -8.165661               0.317794
# 16               0.175175              -0.103770               0.754299
# 17               3.648916              -1.864502               0.305828
# 18              11.411387              -1.222071              -0.252026
# 19              13.149121               0.986040               0.940554
# 20              -3.001751              -5.359769               1.868880
# 21              -1.583268              -5.309025               1.059224
# 22              -0.204191             -10.479878               1.244070
# 23              -3.038060             -11.903646               2.527109
# 24               1.884221              -4.575938               4.343458
# 25              41.613923              14.324165              -8.121010
# 26               1.885895               1.263729              -0.490442
# 27               3.484433              -1.636291              -0.960461
# 28               5.743876              -5.338665               1.136308
# 29              19.278122             -12.431191               5.788046
# 30               0.864190              -0.705742              -2.225665
# 31              -3.463084               3.064036              -2.893535
# 32              -8.362402              27.733006              -5.036068
# 33             -40.575855             -29.137627               1.625523
# 34               9.122511              30.003050              -6.438060
# 35               7.367405              31.989284              -4.953981
# 36               4.096652              -5.721934              -2.402672
# 37               2.970957              -8.514536              -3.421465
# 38              14.223475              -5.716884              -1.132089
# 39              10.815570              -1.944054              -0.372877
#
#     principal component 10        sample   protein
# 0                 7.081987        CAS9-A      CAS9
# 1                -1.470650      CAS9-A.1      CAS9
# 2                 0.233130        CAS9-B      CAS9
# 3                 0.712182      CAS9-B.1      CAS9
# 4                -8.941723         CAV_A       CAV
# 5                -9.245044       CAV_A.1       CAV
# 6                 4.812946         CAV_B       CAV
# 7                 5.114900       CAV_B.1       CAV
# 8                 8.329102       CAVIN_A     CAVIN
# 9                10.713854     CAVIN_A.1     CAVIN
# 10               -3.793078       CAVIN_B     CAVIN
# 11               -2.715648     CAVIN_B.1     CAVIN
# 12               17.438704    CERS2_mg-A  CERS2_mg
# 13               14.905103  CERS2_mg-A.1  CERS2_mg
# 14                7.212861    CERS2_mg-B  CERS2_mg
# 15                9.146537  CERS2_mg-B.1  CERS2_mg
# 16               -3.582709    CERS2-1g_A  CERS2-1g
# 17               -2.072534  CERS2-1g_A.1  CERS2-1g
# 18               -3.856244    CERS2-1g_B  CERS2-1g
# 19               -7.785770  CERS2-1g_B.1  CERS2-1g
# 20               -2.110278       CERS5-A     CERS5
# 21               -1.049842     CERS5-A.1     CERS5
# 22                3.157854       CERS5-B     CERS5
# 23                3.369553     CERS5-B.1     CERS5
# 24                7.155372       Flot2-A     Flot2
# 25              -24.181733     Flot2-A.1     Flot2
# 26               -7.269218       Flot2-B     Flot2
# 27               -6.083341     Flot2-B.1     Flot2
# 28               -0.002771       SPTLC_A     SPTLC
# 29                9.200787     SPTLC_A.1     SPTLC
# 30               -3.952360       SPTLC_B     SPTLC
# 31               -2.948366     SPTLC_B.1     SPTLC
# 32               45.960290        UGCG-A      UGCG
# 33              -32.294953      UGCG-A.1      UGCG
# 34              -14.164044        UGCG-B      UGCG
# 35              -16.098803      UGCG-B.1      UGCG
# 36               -0.260548          WT_A        WT
# 37               -0.240851        WT_A.1        WT
# 38               -0.005913          WT_B        WT
# 39               -0.418739        WT_B.1        WT

# %%
# find explained variance
explained_variance = pca_lipids.explained_variance_ratio_
print('Explained variation per principal component: {}'.format(explained_variance))

plt.figure(figsize=(10,10))
plt.bar(
    x=pcs,
    height=explained_variance
)
plt.xticks(rotation=90)
plt.show()
# Out:
# Explained variation per principal component: [0.12548334 0.08688734 0.07623546 0.06215949 0.04835085 0.04042701
#  0.03531488 0.02891057 0.02863232 0.02631544]

# %%
# which features contribute to the components. it has shape (n_components, n_features)
components_df = pd.DataFrame(pca_lipids.components_, columns=samples, index=pcs)
components_df
# Out:
# Sample Name             Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  \
# principal component 1                           0.010858
# principal component 2                           0.010005
# principal component 3                          -0.031116
# principal component 4                           0.000902
# principal component 5                          -0.029324
# principal component 6                           0.012450
# principal component 7                           0.000148
# principal component 8                          -0.007641
# principal component 9                           0.007209
# principal component 10                          0.004366
#
# Sample Name             Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# principal component 1                           0.011634
# principal component 2                           0.003770
# principal component 3                           0.030419
# principal component 4                          -0.007845
# principal component 5                          -0.005368
# principal component 6                          -0.008465
# principal component 7                          -0.014559
# principal component 8                          -0.006522
# principal component 9                           0.000855
# principal component 10                         -0.004285
#
# Sample Name             Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# principal component 1                          -0.006906
# principal component 2                          -0.001142
# principal component 3                          -0.030776
# principal component 4                           0.008474
# principal component 5                          -0.008680
# principal component 6                           0.017092
# principal component 7                          -0.018821
# principal component 8                          -0.012458
# principal component 9                          -0.008148
# principal component 10                         -0.001063
#
# Sample Name             Hex2Cer 26:2;2 (LCB 18:0;2-H2O)  \
# principal component 1                          0.002079
# principal component 2                         -0.013390
# principal component 3                         -0.000071
# principal component 4                          0.026415
# principal component 5                         -0.009720
# principal component 6                          0.011603
# principal component 7                         -0.013198
# principal component 8                         -0.009926
# principal component 9                          0.001711
# principal component 10                        -0.000809
#
# Sample Name             Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  \
# principal component 1                           0.018801
# principal component 2                          -0.008447
# principal component 3                           0.024457
# principal component 4                          -0.012156
# principal component 5                           0.015846
# principal component 6                          -0.015631
# principal component 7                          -0.004781
# principal component 8                           0.012306
# principal component 9                          -0.016629
# principal component 10                          0.009491
#
# Sample Name             Hex2Cer 26:0;2 (LCB 18:0;2-H2O)  \
# principal component 1                          0.009103
# principal component 2                         -0.012108
# principal component 3                          0.019980
# principal component 4                          0.009726
# principal component 5                          0.006802
# principal component 6                         -0.015667
# principal component 7                         -0.007765
# principal component 8                          0.016104
# principal component 9                         -0.017038
# principal component 10                        -0.004680
#
# Sample Name             Hex2Cer 26:4;3 (LCB 18:0;2-H2O)  \
# principal component 1                         -0.003802
# principal component 2                         -0.008244
# principal component 3                          0.027487
# principal component 4                          0.014026
# principal component 5                          0.012694
# principal component 6                         -0.014290
# principal component 7                          0.002404
# principal component 8                          0.008101
# principal component 9                         -0.013163
# principal component 10                         0.018358
#
# Sample Name             Hex2Cer 26:4;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# principal component 1                                         -0.013510
# principal component 2                                          0.021876
# principal component 3                                          0.010386
# principal component 4                                         -0.013636
# principal component 5                                          0.006928
# principal component 6                                          0.003206
# principal component 7                                          0.007754
# principal component 8                                         -0.010531
# principal component 9                                         -0.008997
# principal component 10                                        -0.000636
#
# Sample Name             Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# principal component 1                                         -0.008660
# principal component 2                                          0.021626
# principal component 3                                          0.018746
# principal component 4                                         -0.010735
# principal component 5                                         -0.013279
# principal component 6                                          0.010866
# principal component 7                                         -0.009113
# principal component 8                                         -0.002330
# principal component 9                                         -0.013214
# principal component 10                                         0.007009
#
# Sample Name             Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  ...  \
# principal component 1                                         -0.004961  ...
# principal component 2                                          0.007334  ...
# principal component 3                                          0.001873  ...
# principal component 4                                         -0.005582  ...
# principal component 5                                         -0.016066  ...
# principal component 6                                         -0.007599  ...
# principal component 7                                         -0.009712  ...
# principal component 8                                         -0.007001  ...
# principal component 9                                         -0.001717  ...
# principal component 10                                         0.031072  ...
#
# Sample Name             DAG 35:0+NH4 (-FA 17:0 (NH4))  \
# principal component 1                       -0.013683
# principal component 2                        0.009568
# principal component 3                        0.017629
# principal component 4                        0.014006
# principal component 5                        0.005399
# principal component 6                        0.026379
# principal component 7                       -0.023455
# principal component 8                        0.004889
# principal component 9                        0.003897
# principal component 10                      -0.011272
#
# Sample Name             DAG 38:4+NH4 (-FA 18:1 (NH4))  \
# principal component 1                       -0.008364
# principal component 2                       -0.017467
# principal component 3                        0.003443
# principal component 4                        0.022513
# principal component 5                       -0.010343
# principal component 6                        0.021758
# principal component 7                       -0.012766
# principal component 8                        0.003454
# principal component 9                        0.006343
# principal component 10                      -0.012737
#
# Sample Name             DAG 38:4+NH4 (-FA 20:3 (NH4))  \
# principal component 1                       -0.007985
# principal component 2                       -0.018944
# principal component 3                        0.007040
# principal component 4                        0.026259
# principal component 5                       -0.007449
# principal component 6                        0.030851
# principal component 7                       -0.012985
# principal component 8                        0.000223
# principal component 9                        0.003085
# principal component 10                      -0.007975
#
# Sample Name             DAG 38:4+NH4 (-FA 20:4 (NH4))  \
# principal component 1                       -0.007365
# principal component 2                       -0.019146
# principal component 3                        0.008156
# principal component 4                        0.030216
# principal component 5                       -0.006810
# principal component 6                        0.024362
# principal component 7                       -0.003688
# principal component 8                       -0.003959
# principal component 9                       -0.000711
# principal component 10                      -0.003255
#
# Sample Name             MADAG 38:2+NH4 (-FA 13:0 (NH4))  \
# principal component 1                          0.003055
# principal component 2                         -0.009472
# principal component 3                         -0.002623
# principal component 4                          0.031712
# principal component 5                          0.000501
# principal component 6                          0.005376
# principal component 7                          0.009215
# principal component 8                         -0.004710
# principal component 9                          0.000358
# principal component 10                        -0.004683
#
# Sample Name             DAG 38:2+NH4 (-FA 16:1 (NH4))  \
# principal component 1                        0.004324
# principal component 2                       -0.007141
# principal component 3                       -0.000030
# principal component 4                        0.040223
# principal component 5                        0.004771
# principal component 6                        0.011311
# principal component 7                        0.008420
# principal component 8                       -0.007348
# principal component 9                       -0.003808
# principal component 10                       0.009133
#
# Sample Name             MADAG 38:2+NH4 (-FA 16:2 (NH4))  \
# principal component 1                         -0.004501
# principal component 2                          0.005941
# principal component 3                          0.006372
# principal component 4                          0.002138
# principal component 5                          0.007206
# principal component 6                          0.006496
# principal component 7                         -0.028853
# principal component 8                          0.033114
# principal component 9                          0.003514
# principal component 10                         0.033548
#
# Sample Name             DAG 38:2+NH4 (-FA 18:0 (NH4))  \
# principal component 1                        0.013817
# principal component 2                        0.003170
# principal component 3                       -0.009833
# principal component 4                        0.032535
# principal component 5                        0.012233
# principal component 6                        0.006502
# principal component 7                        0.010100
# principal component 8                       -0.006495
# principal component 9                       -0.001859
# principal component 10                       0.007390
#
# Sample Name             DAG 38:2+NH4 (-FA 18:1 (NH4))  \
# principal component 1                        0.015870
# principal component 2                        0.006412
# principal component 3                       -0.012573
# principal component 4                        0.027573
# principal component 5                        0.014067
# principal component 6                        0.007529
# principal component 7                        0.009699
# principal component 8                       -0.006298
# principal component 9                       -0.000053
# principal component 10                       0.003472
#
# Sample Name             MADAG 38:2+NH4 (-FA 18:2 (NH4))
# principal component 1                          0.004582
# principal component 2                          0.001638
# principal component 3                         -0.002227
# principal component 4                          0.026281
# principal component 5                          0.008435
# principal component 6                          0.024634
# principal component 7                         -0.010641
# principal component 8                          0.005412
# principal component 9                          0.002803
# principal component 10                         0.012633
#
# [10 rows x 5479 columns]

# %% [markdown]
# # Graph PCA (Transposed)

# %%
import altair as alt

# %%
# chart principal components
click = alt.selection_point(fields=['protein'])

pca= alt.Chart(df_pca).mark_point().encode(
    x='principal component 1:Q',
    y='principal component 2:Q',
    color=alt.condition(click, 'protein:N', alt.value('lightgray')),
    tooltip=['sample', 'protein']
).properties(
    width=400,
    height=500,
    title='Principal Components Analysis'
).add_params(
    click
)

pca
# Out:
# alt.Chart(...)

# %% [markdown]
# # Save Chart

# %%
# save chart to html
pca.save('graphs/pos_mode_whole_dataset/pca-transposed.html')
