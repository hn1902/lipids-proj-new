# %%
# import modules
import pandas as pd
import glob
import re
import matplotlib.pyplot as plt

# %% [markdown]
# # Import DataFrames

# %%
# get raw data
df = pd.read_csv('dataframes/pos_df.csv')
df.head()
# Out:
#                         Sample Name    CAS9-A  CAS9-A.1    CAS9-B  CAS9-B.1  \
# 0  Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  167.0000  143.0000  125.0000  132.0000
# 1  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)   53.2158   52.8015   47.4908   76.2783
# 2  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  167.8122  131.3388  220.0689  128.3439
# 3   Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   54.0000   47.0000   39.0000   44.0000
# 4  Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  391.2240  326.4641  444.7720  385.3202
#
#       CAV_A   CAV_A.1     CAV_B   CAV_B.1   CAVIN_A  ...   SPTLC_B  SPTLC_B.1  \
# 0  171.6091  182.9007  120.0000  120.0000  281.3523  ...  130.0000   142.0000
# 1   27.6563   23.0569    9.0712   24.0712    0.0000  ...    0.0000     2.1176
# 2  342.9760  331.4596  268.9979  289.4925  295.0869  ...  290.0353   223.3067
# 3   74.0000   64.0000   84.5341   88.7361   70.0000  ...   44.0000    37.0000
# 4  175.0126  296.5953  238.6997  214.9442  215.1018  ...  309.7805   272.9937
#
#      UGCG-A  UGCG-A.1    UGCG-B  UGCG-B.1      WT_A    WT_A.1      WT_B  \
# 0   68.0529   46.4729   88.0000   91.0000  229.5233  278.1255  206.0000
# 1   47.2560   62.7063   11.1856    0.0000   10.8768    6.0672    0.0000
# 2  187.9922  219.2679  231.3212  219.2373  329.9421  313.2847  251.0406
# 3   48.6404   51.9843   38.9995   52.0000   62.0000   57.0000   51.0000
# 4  373.2111  292.2522  348.9607  348.3176  304.3199  271.4133  303.6544
#
#      WT_B.1
# 0  182.0000
# 1   34.4747
# 2  226.8066
# 3   40.0000
# 4  253.3654
#
# [5 rows x 43 columns]

# %%
# get lipid metadata
df_meta = pd.read_csv('dataframes/pos_lipids_df_meta.csv')
df_meta.sample(5)
# Out:
#                                           Sample Name Head Group  \
# 387                       GD3 30:3;2 (LCB 18:0;2-H2O)        GD3
# 4363                    TAG 54:3+NH4 (-FA 18:0 (NH4))        TAG
# 3632                     GM1 44:1;3 (LCB 18:0;2-2H2O)        GM1
# 3498     GM2 34:1;3 (LCB 18:2;2-2H20,LCB 18:1;3-3H2O)        GM2
# 191   Hex2Cer 30:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)    Hex2Cer
#
#       Acyl Chain Length  Unsaturation
# 387                  30             3
# 4363                 54             3
# 3632                 44             1
# 3498                 34             1
# 191                  30             3

# %%
# get experiment metadata
df_exps = pd.read_csv('dataframes/pos_exps_df_meta.csv')
df_exps.sample(5)
# Out:
#        sample protein
# 8     CAVIN_A   CAVIN
# 23  CERS5-B.1   CERS5
# 20    CERS5-A   CERS5
# 0      CAS9-A    CAS9
# 38       WT_A      WT

# %% [markdown]
# # Principal Components Analysis (Transposed)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# drop the blank columns and transpose dataframe
samples = df["Sample Name"]
df_dropped = df.drop(["Sample Name", "RAJU-Blank", "RAJU-Blank.1"], axis=1)

df_dropped = df_dropped.T
exps = df_dropped.index

x = df_dropped.values

# for each column, standardize the values
x = StandardScaler().fit_transform(x)

# check random column for standardization (mean=0, standard deviation=1)
x.shape, np.mean(x[:,20]), np.std(x[:,20])
# Out:
# ((40, 5479), 4.4408920985006264e-17, 1.0)

# %%
# create dataframe with standardized values
df_standardized = pd.DataFrame(x, columns=samples)
df_standardized = df_standardized.set_index(exps)
df_standardized.head(10)
# Out:
# Sample Name  Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                              -0.119632
# CAS9-A.1                            -0.553561
# CAS9-B                              -0.879008
# CAS9-B.1                            -0.752445
# CAV_A                               -0.036297
# CAV_A.1                              0.167859
# CAV_B                               -0.969410
# CAV_B.1                             -0.969410
# CAVIN_A                              1.947901
# CAVIN_A.1                            0.193994
#
# Sample Name  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                               1.767019
# CAS9-A.1                             1.746037
# CAS9-B                               1.477073
# CAS9-B.1                             2.935033
# CAV_A                                0.472543
# CAV_A.1                              0.239604
# CAV_B                               -0.468710
# CAV_B.1                              0.290974
# CAVIN_A                             -0.928126
# CAVIN_A.1                           -0.226649
#
# Sample Name  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                              -1.638565
# CAS9-A.1                            -2.330926
# CAS9-B                              -0.646596
# CAS9-B.1                            -2.387777
# CAV_A                                1.686503
# CAV_A.1                              1.467892
# CAV_B                                0.282205
# CAV_B.1                              0.671246
# CAVIN_A                              0.777443
# CAVIN_A.1                           -0.553325
#
# Sample Name  Hex2Cer 26:2;2 (LCB 18:0;2-H2O)  \
# CAS9-A                              0.206113
# CAS9-A.1                           -0.207008
# CAS9-B                             -0.679147
# CAS9-B.1                           -0.384060
# CAV_A                               1.386459
# CAV_A.1                             0.796286
# CAV_B                               2.008153
# CAV_B.1                             2.256143
# CAVIN_A                             1.150389
# CAVIN_A.1                           0.029061
#
# Sample Name  Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  \
# CAS9-A                               1.929826
# CAS9-A.1                             1.015202
# CAS9-B                               2.686101
# CAS9-B.1                             1.846445
# CAV_A                               -1.123793
# CAV_A.1                              0.593356
# CAV_B                               -0.224321
# CAV_B.1                             -0.559827
# CAVIN_A                             -0.557601
# CAVIN_A.1                           -0.563991
#
# Sample Name  Hex2Cer 26:0;2 (LCB 18:0;2-H2O)  Hex2Cer 26:4;3 (LCB 18:0;2-H2O)  \
# CAS9-A                              0.169306                         2.227004
# CAS9-A.1                            0.228176                        -0.659004
# CAS9-B                              2.670966                        -0.659004
# CAS9-B.1                            0.127014                         2.050161
# CAV_A                               0.761665                        -0.659004
# CAV_A.1                             0.310385                        -0.659004
# CAV_B                              -0.329849                         2.049686
# CAV_B.1                             1.425733                         0.806763
# CAVIN_A                             0.745717                        -0.659004
# CAVIN_A.1                          -0.949952                         0.258598
#
# Sample Name  Hex2Cer 26:4;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# CAS9-A                                              0.471287
# CAS9-A.1                                           -0.757276
# CAS9-B                                              0.207133
# CAS9-B.1                                           -0.757276
# CAV_A                                              -0.757276
# CAV_A.1                                            -0.757276
# CAV_B                                              -0.757276
# CAV_B.1                                            -0.757276
# CAVIN_A                                            -0.757276
# CAVIN_A.1                                           1.358562
#
# Sample Name  Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# CAS9-A                                              0.400821
# CAS9-A.1                                           -0.763288
# CAS9-B                                              1.172339
# CAS9-B.1                                            1.298701
# CAV_A                                               1.040952
# CAV_A.1                                             0.783203
# CAV_B                                              -0.763288
# CAV_B.1                                            -0.763288
# CAVIN_A                                             1.040952
# CAVIN_A.1                                           1.291696
#
# Sample Name  Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  ...  \
# CAS9-A                                             -0.494894  ...
# CAS9-A.1                                           -0.494894  ...
# CAS9-B                                             -0.494894  ...
# CAS9-B.1                                            2.624122  ...
# CAV_A                                              -0.494894  ...
# CAV_A.1                                             1.409335  ...
# CAV_B                                              -0.494894  ...
# CAV_B.1                                            -0.494894  ...
# CAVIN_A                                             0.929145  ...
# CAVIN_A.1                                          -0.494894  ...
#
# Sample Name  DAG 35:0+NH4 (-FA 17:0 (NH4))  DAG 38:4+NH4 (-FA 18:1 (NH4))  \
# CAS9-A                           -0.482176                      -0.398903
# CAS9-A.1                         -0.482176                      -0.398903
# CAS9-B                           -0.482176                      -0.398903
# CAS9-B.1                         -0.482176                      -0.398903
# CAV_A                             3.019255                       2.518582
# CAV_A.1                           2.669112                       3.887279
# CAV_B                             1.531147                       2.266454
# CAV_B.1                           1.239361                       1.582106
# CAVIN_A                          -0.482176                      -0.398903
# CAVIN_A.1                        -0.482176                      -0.398903
#
# Sample Name  DAG 38:4+NH4 (-FA 20:3 (NH4))  DAG 38:4+NH4 (-FA 20:4 (NH4))  \
# CAS9-A                           -0.370975                      -0.350245
# CAS9-A.1                         -0.370975                      -0.350245
# CAS9-B                           -0.370975                      -0.350245
# CAS9-B.1                         -0.370975                      -0.350245
# CAV_A                             2.754141                       3.625649
# CAV_A.1                           2.924216                      -0.350245
# CAV_B                             2.860438                       2.964777
# CAV_B.1                           2.924216                       3.316531
# CAVIN_A                          -0.370975                      -0.350245
# CAVIN_A.1                        -0.370975                      -0.350245
#
# Sample Name  MADAG 38:2+NH4 (-FA 13:0 (NH4))  DAG 38:2+NH4 (-FA 16:1 (NH4))  \
# CAS9-A                             -0.484760                      -0.600253
# CAS9-A.1                           -0.484760                      -0.600253
# CAS9-B                             -0.484760                      -0.600253
# CAS9-B.1                           -0.484760                      -0.600253
# CAV_A                               1.846327                       0.151630
# CAV_A.1                            -0.484760                       0.452383
# CAV_B                               1.740368                       2.106525
# CAV_B.1                             1.263555                       2.557654
# CAVIN_A                            -0.484760                      -0.600253
# CAVIN_A.1                           1.210576                       1.003763
#
# Sample Name  MADAG 38:2+NH4 (-FA 16:2 (NH4))  DAG 38:2+NH4 (-FA 18:0 (NH4))  \
# CAS9-A                             -0.318859                      -0.618937
# CAS9-A.1                           -0.318859                      -0.618937
# CAS9-B                             -0.318859                      -0.618937
# CAS9-B.1                           -0.318859                      -0.618937
# CAV_A                               2.785081                      -0.100456
# CAV_A.1                             1.882117                       0.634059
# CAV_B                              -0.318859                       0.979713
# CAV_B.1                            -0.318859                       0.893300
# CAVIN_A                            -0.318859                      -0.618937
# CAVIN_A.1                           2.446470                       1.238954
#
# Sample Name  DAG 38:2+NH4 (-FA 18:1 (NH4))  MADAG 38:2+NH4 (-FA 18:2 (NH4))
# CAS9-A                           -0.593602                        -0.620205
# CAS9-A.1                         -0.593602                        -0.620205
# CAS9-B                           -0.593602                        -0.620205
# CAS9-B.1                         -0.593602                        -0.620205
# CAV_A                             0.801032                         1.933684
# CAV_A.1                           0.964328                         2.275976
# CAV_B                             0.650977                         1.529318
# CAV_B.1                           0.425893                         1.430000
# CAVIN_A                          -0.593602                        -0.620205
# CAVIN_A.1                        -0.593602                         1.779386
#
# [10 rows x 5479 columns]

# %%
# do PCA
from sklearn.decomposition import PCA
pca_lipids = PCA(n_components=10)
principal_components = pca_lipids.fit_transform(x)

# %%
# create df with pca values

# create list of columns
pcs = []
for i in range(1,11):
    pcs.append('principal component ' + str(i))
# print(pcs)

# create df
df_pca = pd.DataFrame(principal_components, columns=pcs)
df_pca["sample"] = exps
df_pca = df_pca.merge(df_exps, on='sample')
df_pca
# Out:
#     principal component 1  principal component 2  principal component 3  \
# 0               39.878604             -12.062030              44.447697
# 1               44.295494             -10.883868              43.854811
# 2               46.200347             -15.622895              41.293671
# 3               31.600443             -11.752565              27.898431
# 4              -12.783920             -11.643211              -6.138718
# 5              -15.287201             -12.537097              -6.167281
# 6              -16.213377             -37.552008              24.654770
# 7              -15.947377             -38.698696              23.571196
# 8               10.336902              14.009873              -1.847076
# 9                9.744614              12.675201              -3.855421
# 10              17.345075              -1.446010             -14.836834
# 11              18.769855              -2.160654             -12.834605
# 12             -24.784245              12.755258              -6.275893
# 13             -25.102324              14.955109              -4.142841
# 14             -22.354832              11.102823              -9.323234
# 15             -19.464706               6.654015             -10.739676
# 16             -11.136685              -7.654412             -17.592005
# 17             -13.042379              -7.248747             -17.459038
# 18             -12.801196             -15.458898              -4.822003
# 19             -11.699279             -16.128552              -0.570305
# 20              -2.515935              -4.545150             -18.586739
# 21              -3.861264              -4.949065             -19.241776
# 22              -8.695588               9.907885              -8.872261
# 23              -6.451786              10.915144              -9.630994
# 24             -26.322530              44.573511               9.245718
# 25             -37.826696              68.579545              22.155226
# 26              -3.646933              -5.694976             -16.133477
# 27              -1.287520              -5.480891             -17.838820
# 28             -25.721001             -22.970256              -6.607918
# 29             -28.996807             -27.375527              -7.092241
# 30             -19.138492             -23.794027              -7.002244
# 31             -18.446690             -24.542187              -7.114372
# 32             -16.281907              29.986093              31.800664
# 33             -19.855708              40.303395              43.812332
# 34              -4.671277             -13.347743               7.833262
# 35              -1.376172             -11.137858               9.066786
# 36              52.251907              16.435069             -26.843270
# 37              59.394948              19.777693             -27.143324
# 38              49.816631              16.883196             -21.424604
# 39              46.079012              15.173511             -19.497596
#
#     principal component 4  principal component 5  principal component 6  \
# 0              -13.214600              -9.379596              -1.176451
# 1              -13.829808             -10.420936              -2.067215
# 2              -35.806120             -20.992107              -0.899758
# 3              -23.627700              -9.036433              -4.842276
# 4               -5.899572              -9.764798              21.575610
# 5               -3.547119              -8.118510              20.693272
# 6               51.930658               1.843551              28.215570
# 7               51.185730              -1.005912              27.486120
# 8               -1.776937              -3.150492              16.299872
# 9                0.945320               0.170876              14.748569
# 10              -3.015233              -3.265127              12.163891
# 11              -3.520595              -2.790951              13.503564
# 12              -1.436942             -16.586059              -8.878412
# 13              -1.489928             -12.905475              -8.558598
# 14              -4.125234             -17.871596              -4.985589
# 15              -1.907270             -17.462210              -7.576196
# 16              -2.156723              -7.869566             -11.460602
# 17              -0.287393              -5.536118             -12.101490
# 18              21.451781             -11.017343             -18.491217
# 19              25.301733             -11.568824             -21.483734
# 20              -3.377993             -13.307318              -6.281518
# 21              -4.382038             -14.361389              -6.178538
# 22               0.678921             -10.288760              -5.382425
# 23              -0.032401             -11.894286              -3.951347
# 24              -4.642670              -4.779195              10.765707
# 25              -9.763104              -6.967192              36.702245
# 26              -6.461392             -11.356548              -8.482002
# 27              -7.939509             -10.781822              -9.316565
# 28             -23.673998              29.433965               2.158314
# 29             -33.271859              49.970773               9.284591
# 30             -25.072952              18.448592               3.099676
# 31             -26.171322              19.816727               7.132958
# 32              11.156318              26.881807             -19.453730
# 33              13.635032              32.984208             -25.371328
# 34              13.808246               7.044872             -22.874659
# 35              12.063172               8.633442             -25.037561
# 36              12.372027              12.890725               3.618179
# 37              12.250002              14.222343               8.962735
# 38              17.275349              21.338150              -0.490419
# 39              16.376118              18.798531              -1.069245
#
#     principal component 7  principal component 8  principal component 9  \
# 0                8.577355               0.148986              -0.148890
# 1               12.881243             -24.138611              56.701439
# 2               -1.821495               4.497931             -42.312202
# 3                0.483622               6.024042             -14.861678
# 4              -24.906021              16.487721               6.955154
# 5              -23.531785              11.381415               5.892195
# 6                5.640386             -12.939633             -10.592994
# 7                2.952763              -5.576488              -6.023595
# 8              -18.551163               2.400133               8.221189
# 9              -22.183740               1.079372               3.569375
# 10             -18.909983              12.587809              11.184736
# 11             -19.549184              13.231962              10.693064
# 12               3.731829              -8.264570               1.914067
# 13               1.103587              -9.120107              -2.217719
# 14               2.683987             -15.237681              -3.211516
# 15              -1.794064             -10.768383              -2.116953
# 16               0.827970              -0.321169               1.162881
# 17               4.239459              -2.055637               0.456632
# 18              10.884682               2.059035              -3.515206
# 19              11.378973               4.613579              -0.610203
# 20              -2.060739              -4.499211              -1.401779
# 21              -0.437137              -3.662326              -1.967656
# 22               0.495985              -8.395099              -1.578334
# 23              -2.992921              -8.996285              -2.154080
# 24               2.153009              -6.694402               0.809221
# 25              41.305707              17.688924              -1.731054
# 26               2.655966               1.136431               0.701537
# 27               4.333889              -1.220728              -1.637965
# 28               6.226034              -4.916353               1.348700
# 29              20.057593             -12.128696              -0.490979
# 30              -0.075224              -0.788034              -1.211014
# 31              -4.585339               1.290335              -3.191698
# 32             -10.019020              31.967948               3.832298
# 33             -39.180959             -29.058591              -9.217579
# 34               9.116569              25.860835               7.285649
# 35               7.157598              29.541660               8.814916
# 36               3.624600              -4.290890              -5.039311
# 37               3.339109              -4.665709              -9.204289
# 38              14.265412              -3.424689              -3.263547
# 39              10.481444              -0.834827              -1.842812
#
#     principal component 10        sample   protein
# 0                 3.123277        CAS9-A      CAS9
# 1                 1.971025      CAS9-A.1      CAS9
# 2                 1.106425        CAS9-B      CAS9
# 3                 1.149787      CAS9-B.1      CAS9
# 4                -5.691946         CAV_A       CAV
# 5                -5.166800       CAV_A.1       CAV
# 6                 6.058263         CAV_B       CAV
# 7                 2.723295       CAV_B.1       CAV
# 8                 6.124913       CAVIN_A     CAVIN
# 9                 9.146974     CAVIN_A.1     CAVIN
# 10               -7.299324       CAVIN_B     CAVIN
# 11               -6.698533     CAVIN_B.1     CAVIN
# 12               16.879387    CERS2_mg-A  CERS2_mg
# 13               13.353277  CERS2_mg-A.1  CERS2_mg
# 14                4.260473    CERS2_mg-B  CERS2_mg
# 15                8.133547  CERS2_mg-B.1  CERS2_mg
# 16               -2.485125    CERS2-1g_A  CERS2-1g
# 17               -1.553464  CERS2-1g_A.1  CERS2-1g
# 18               -3.077183    CERS2-1g_B  CERS2-1g
# 19               -4.829965  CERS2-1g_B.1  CERS2-1g
# 20               -0.935047       CERS5-A     CERS5
# 21                0.161800     CERS5-A.1     CERS5
# 22                6.768547       CERS5-B     CERS5
# 23                5.540910     CERS5-B.1     CERS5
# 24               -0.634239       Flot2-A     Flot2
# 25              -20.620366     Flot2-A.1     Flot2
# 26               -6.624782       Flot2-B     Flot2
# 27               -6.177183     Flot2-B.1     Flot2
# 28               -1.470338       SPTLC_A     SPTLC
# 29                8.719628     SPTLC_A.1     SPTLC
# 30               -2.077964       SPTLC_B     SPTLC
# 31               -2.760853     SPTLC_B.1     SPTLC
# 32               49.466402        UGCG-A      UGCG
# 33              -31.264683      UGCG-A.1      UGCG
# 34              -18.719840        UGCG-B      UGCG
# 35              -18.910656      UGCG-B.1      UGCG
# 36                1.278867          WT_A        WT
# 37               -0.308001        WT_A.1        WT
# 38                0.814909          WT_B        WT
# 39                0.524585        WT_B.1        WT

# %%
# find explained variance
explained_variance = pca_lipids.explained_variance_ratio_
print('Explained variation per principal component: {}'.format(explained_variance))

plt.figure(figsize=(10,10))
plt.bar(
    x=pcs,
    height=explained_variance
)
plt.xticks(rotation=90)
plt.show()
# Out:
# Explained variation per principal component: [0.12548334 0.08688733 0.07623542 0.062159   0.04835058 0.0404368
#  0.03526633 0.02900665 0.02861343 0.02646663]

# %%
# which features contribute to the components. it has shape (n_components, n_features)
components_df = pd.DataFrame(pca_lipids.components_, columns=samples, index=pcs)
components_df
# Out:
# Sample Name             Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  \
# principal component 1                           0.010857
# principal component 2                           0.010005
# principal component 3                          -0.031130
# principal component 4                           0.000895
# principal component 5                          -0.029235
# principal component 6                           0.012416
# principal component 7                           0.001258
# principal component 8                          -0.007311
# principal component 9                           0.003549
# principal component 10                          0.005449
#
# Sample Name             Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# principal component 1                           0.011632
# principal component 2                           0.003766
# principal component 3                           0.030387
# principal component 4                          -0.007892
# principal component 5                          -0.005277
# principal component 6                          -0.008638
# principal component 7                          -0.014010
# principal component 8                          -0.004184
# principal component 9                          -0.003213
# principal component 10                          0.000347
#
# Sample Name             Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  \
# principal component 1                          -0.006907
# principal component 2                          -0.001141
# principal component 3                          -0.030805
# principal component 4                           0.008480
# principal component 5                          -0.008686
# principal component 6                           0.016869
# principal component 7                          -0.017903
# principal component 8                          -0.007035
# principal component 9                          -0.014023
# principal component 10                          0.000438
#
# Sample Name             Hex2Cer 26:2;2 (LCB 18:0;2-H2O)  \
# principal component 1                          0.002075
# principal component 2                         -0.013376
# principal component 3                         -0.000077
# principal component 4                          0.026439
# principal component 5                         -0.009310
# principal component 6                          0.011777
# principal component 7                         -0.012560
# principal component 8                         -0.004897
# principal component 9                         -0.004984
# principal component 10                         0.005493
#
# Sample Name             Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  \
# principal component 1                           0.018803
# principal component 2                          -0.008444
# principal component 3                           0.024466
# principal component 4                          -0.012104
# principal component 5                           0.015876
# principal component 6                          -0.015576
# principal component 7                          -0.005354
# principal component 8                           0.016790
# principal component 9                          -0.011342
# principal component 10                          0.008471
#
# Sample Name             Hex2Cer 26:0;2 (LCB 18:0;2-H2O)  \
# principal component 1                          0.009096
# principal component 2                         -0.012129
# principal component 3                          0.019968
# principal component 4                          0.009724
# principal component 5                          0.006577
# principal component 6                         -0.015091
# principal component 7                         -0.008262
# principal component 8                          0.026878
# principal component 9                         -0.012735
# principal component 10                        -0.003537
#
# Sample Name             Hex2Cer 26:4;3 (LCB 18:0;2-H2O)  \
# principal component 1                         -0.003800
# principal component 2                         -0.008231
# principal component 3                          0.027460
# principal component 4                          0.013993
# principal component 5                          0.012719
# principal component 6                         -0.014451
# principal component 7                          0.002733
# principal component 8                          0.010758
# principal component 9                         -0.008421
# principal component 10                         0.015261
#
# Sample Name             Hex2Cer 26:4;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# principal component 1                                         -0.013506
# principal component 2                                          0.021895
# principal component 3                                          0.010424
# principal component 4                                         -0.013572
# principal component 5                                          0.007147
# principal component 6                                          0.003406
# principal component 7                                          0.006886
# principal component 8                                         -0.011311
# principal component 9                                         -0.013900
# principal component 10                                        -0.003235
#
# Sample Name             Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  \
# principal component 1                                         -0.008660
# principal component 2                                          0.021634
# principal component 3                                          0.018780
# principal component 4                                         -0.010647
# principal component 5                                         -0.013177
# principal component 6                                          0.011612
# principal component 7                                         -0.011563
# principal component 8                                          0.003005
# principal component 9                                         -0.016570
# principal component 10                                         0.005399
#
# Sample Name             Hex2Cer 26:3;3 (LCB 18:1;2-H2O,LCB 18:0;3-2H2O)  ...  \
# principal component 1                                         -0.004967  ...
# principal component 2                                          0.007312  ...
# principal component 3                                          0.001873  ...
# principal component 4                                         -0.005715  ...
# principal component 5                                         -0.016054  ...
# principal component 6                                         -0.007016  ...
# principal component 7                                         -0.009191  ...
# principal component 8                                         -0.001308  ...
# principal component 9                                         -0.002342  ...
# principal component 10                                         0.035773  ...
#
# Sample Name             DAG 35:0+NH4 (-FA 17:0 (NH4))  \
# principal component 1                       -0.013691
# principal component 2                        0.009562
# principal component 3                        0.017620
# principal component 4                        0.014016
# principal component 5                        0.005592
# principal component 6                        0.026858
# principal component 7                       -0.023237
# principal component 8                        0.011171
# principal component 9                       -0.001689
# principal component 10                      -0.006914
#
# Sample Name             DAG 38:4+NH4 (-FA 18:1 (NH4))  \
# principal component 1                       -0.008373
# principal component 2                       -0.017476
# principal component 3                        0.003464
# principal component 4                        0.022549
# principal component 5                       -0.010032
# principal component 6                        0.022734
# principal component 7                       -0.013433
# principal component 8                        0.011056
# principal component 9                       -0.001064
# principal component 10                      -0.005631
#
# Sample Name             DAG 38:4+NH4 (-FA 20:3 (NH4))  \
# principal component 1                       -0.007990
# principal component 2                       -0.018953
# principal component 3                        0.007051
# principal component 4                        0.026285
# principal component 5                       -0.007226
# principal component 6                        0.031614
# principal component 7                       -0.013537
# principal component 8                        0.006500
# principal component 9                       -0.002456
# principal component 10                      -0.002361
#
# Sample Name             DAG 38:4+NH4 (-FA 20:4 (NH4))  \
# principal component 1                       -0.007369
# principal component 2                       -0.019149
# principal component 3                        0.008180
# principal component 4                        0.030268
# principal component 5                       -0.006708
# principal component 6                        0.025097
# principal component 7                       -0.004507
# principal component 8                        0.002363
# principal component 9                       -0.006149
# principal component 10                      -0.000602
#
# Sample Name             MADAG 38:2+NH4 (-FA 13:0 (NH4))  \
# principal component 1                          0.003049
# principal component 2                         -0.009474
# principal component 3                         -0.002577
# principal component 4                          0.031751
# principal component 5                          0.000737
# principal component 6                          0.006296
# principal component 7                          0.007114
# principal component 8                          0.002226
# principal component 9                         -0.006786
# principal component 10                        -0.000254
#
# Sample Name             DAG 38:2+NH4 (-FA 16:1 (NH4))  \
# principal component 1                        0.004321
# principal component 2                       -0.007143
# principal component 3                        0.000030
# principal component 4                        0.040321
# principal component 5                        0.004861
# principal component 6                        0.012582
# principal component 7                        0.006200
# principal component 8                        0.000633
# principal component 9                       -0.012374
# principal component 10                       0.011976
#
# Sample Name             MADAG 38:2+NH4 (-FA 16:2 (NH4))  \
# principal component 1                         -0.004508
# principal component 2                          0.005948
# principal component 3                          0.006389
# principal component 4                          0.002157
# principal component 5                          0.007590
# principal component 6                          0.007209
# principal component 7                         -0.030862
# principal component 8                          0.036593
# principal component 9                          0.008560
# principal component 10                         0.039962
#
# Sample Name             DAG 38:2+NH4 (-FA 18:0 (NH4))  \
# principal component 1                        0.013812
# principal component 2                        0.003170
# principal component 3                       -0.009784
# principal component 4                        0.032621
# principal component 5                        0.012362
# principal component 6                        0.007614
# principal component 7                        0.008173
# principal component 8                        0.000920
# principal component 9                       -0.011782
# principal component 10                       0.010402
#
# Sample Name             DAG 38:2+NH4 (-FA 18:1 (NH4))  \
# principal component 1                        0.015865
# principal component 2                        0.006406
# principal component 3                       -0.012528
# principal component 4                        0.027679
# principal component 5                        0.014181
# principal component 6                        0.008842
# principal component 7                        0.008230
# principal component 8                        0.003221
# principal component 9                       -0.010899
# principal component 10                       0.007222
#
# Sample Name             MADAG 38:2+NH4 (-FA 18:2 (NH4))
# principal component 1                          0.004576
# principal component 2                          0.001639
# principal component 3                         -0.002201
# principal component 4                          0.026330
# principal component 5                          0.008717
# principal component 6                          0.025980
# principal component 7                         -0.012310
# principal component 8                          0.010385
# principal component 9                         -0.003113
# principal component 10                         0.016451
#
# [10 rows x 5479 columns]

# %% [markdown]
# # Graph PCA (Transposed)

# %%
import altair as alt

# %%
# chart principal components
click = alt.selection_point(fields=['protein'])

pca= alt.Chart(df_pca).mark_point().encode(
    x='principal component 1:Q',
    y='principal component 2:Q',
    color=alt.condition(click, 'protein:N', alt.value('lightgray')),
    tooltip=['sample', 'protein']
).properties(
    width=400,
    height=500,
    title='Principal Components Analysis'
).add_params(
    click
)

pca
# Out:
# alt.Chart(...)

# %% [markdown]
# # Confidence Ellipse

# %%
# add confidence ellipse
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    """
    Create a plot of the covariance confidence ellipse of *x* and *y*.

    Parameters
    ----------
    x, y : array-like, shape (n, )
        Input data.

    ax : matplotlib.axes.Axes
        The axes object to draw the ellipse into.

    n_std : float
        The number of standard deviations to determine the ellipse's radiuses.

    **kwargs
        Forwarded to `~matplotlib.patches.Ellipse`

    Returns
    -------
    matplotlib.patches.Ellipse
    """
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])
    # Using a special case to obtain the eigenvalues of this
    # two-dimensional dataset.
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    # Calculating the standard deviation of x from
    # the squareroot of the variance and multiplying
    # with the given number of standard deviations.
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    # calculating the standard deviation of y ...
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

# %%
i = 0
fig, ax_nstd = plt.subplots(figsize=(10,10 ))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
'#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

for protein in df_pca['protein'].unique():
    x = df_pca[df_pca['protein'] == protein]['principal component 1']
    y = df_pca[df_pca['protein'] == protein]['principal component 2']
    
    ax_nstd.scatter(x, y, color=colors[i])
    confidence_ellipse(x, y, ax_nstd, n_std=3,
                   label=protein, alpha=0.5, facecolor=colors[i], edgecolor=colors[i], linestyle=':')
    i += 1


ax_nstd.grid()
ax_nstd.legend()
plt.show()

# %%
def confidence_ellipse_2(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    """
    Create a plot of the covariance confidence ellipse of *x* and *y*.

    Parameters
    ----------
    x, y : array-like, shape (n, )
        Input data.

    ax : matplotlib.axes.Axes
        The axes object to draw the ellipse into.

    n_std : float
        The number of standard deviations to determine the ellipse's radiuses.

    **kwargs
        Forwarded to `~matplotlib.patches.Ellipse`

    Returns
    -------
    matplotlib.patches.Ellipse
    """
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])
    # Using a special case to obtain the eigenvalues of this
    # two-dimensional dataset.
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    # Calculating the standard deviation of x from
    # the squareroot of the variance and multiplying
    # with the given number of standard deviations.
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    # calculating the standard deviation of y ...
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    
    return ellipse

# %%
fig,ax=plt.subplots(figsize=(1,1))
plt.scatter(x,y)
ell = confidence_ellipse(x, y, ax)
ax.add_patch(ell)

# %% [markdown]
# # Save Chart

# %%
# save chart to html
# pca.save('graphs/pos_mode_whole_dataset/pca-transposed.html')
