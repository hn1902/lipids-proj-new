# %% [markdown]
# # Columns
# 1) input: list of all columns + group (metadata)
# 2) df.drop(df.columns not in input_columns)
#
# questions:
# - how to know which column/row in metadata table has column names? if column metadata >2 columns? specify format?
#
#
# Flow:
# 1) submit dataframe
# 2) optional: submit header
# 3) optional: submit lipid categories
# 4) how many column levels?
#     4a) which column level would you like to use for table?
# 5) how many index levels (columns about lipids?)
#     5a) which column contains individual lipid species?
# 6) which columns/indices would you like to drop?
#     6a)

# %%
import pandas as pd
header = pd.read_csv('data/csv/dgat/a1_header.csv')
hT = header.T
hT.columns = hT.iloc[0]
hT = hT[1:]
hT
# Out:
# shortname          fullname      cohort
# 63          VilERT-G519R-63       G519R
# 73            VilERT-M5B-73         iKO
# 76            VilERT-M5B-76         iKO
# 80          VilERT-G519R-80       G519R
# 83          VilERT-G519R-83       G519R
# 86          VilERT-G519R-86     Control
# 89          VilERT-G519R-89         iKO
# 93          VilERT-G519R-93         iKO
# 94          VilERT-G519R-94     Control
# 108        VilERT-G519R-108       G519R
# 110        VilERT-G519R-110     Control
# 112        VilERT-G519R-112     Control
# 116        VilERT-G519R-116       G519R
# 117        VilERT-G519R-117     Control
# 195            Lrig-M5B-195         iKO
# 196            Lrig-M5B-196         iKO
# 248           Lrig1-M5B-248    Lrig1-D3
# 249           Lrig1-M5B-249    Lrig1-D3
# 255           Lrig1-M5B-255    Lrig1-D3
# 257           Lrig1-M5B-257    Lrig1-D3
# ALI                 H655ALI    DGAT-ALI
# Lipid             H655Lipid  DGAT-Lipid

# %%
df_a1 = pd.read_csv('data/csv/dgat/a1_pmol.csv')
df_a1.set_index(list(df_a1.columns[:3]), inplace=True)
df_a1.columns = [list(df_a1.columns), list(df_a1.iloc[0]), list(df_a1.iloc[1])]
df_a1 = df_a1.droplevel('Unnamed: 0', axis=0)
df_a1 = df_a1[2:]
# Out:
# MultiIndex([(  'CE 13:0;0',  'CE'),
#             (  'CE 16:0;0',  'CE'),
#             (  'CE 16:1;0',  'CE'),
#             (  'CE 17:0;0',  'CE'),
#             (  'CE 18:0;0',  'CE'),
#             (  'CE 18:1;0',  'CE'),
#             (  'CE 18:2;0',  'CE'),
#             (  'CE 18:3;0',  'CE'),
#             (  'CE 20:2;0',  'CE'),
#             (  'CE 20:3;0',  'CE'),
#             ...
#             ( 'TAG 60:5;0', 'TAG'),
#             ( 'TAG 60:6;0', 'TAG'),
#             ( 'TAG 60:7;0', 'TAG'),
#             ( 'TAG 60:8;0', 'TAG'),
#             ( 'TAG 60:9;0', 'TAG'),
#             ('TAG 62:11;0', 'TAG'),
#             ('TAG 62:12;0', 'TAG'),
#             ('TAG 62:13;0', 'TAG'),
#             ('TAG 62:14;0', 'TAG'),
#             ('TAG 62:15;0', 'TAG')],
#            names=['feature', 'class'], length=1421)

# %%
df_a3 = pd.read_csv('data/csv/dgat/a3_pmol.csv')
df_a3.
# Out:
#                x class structuralcategory functionalcategory  totallength  \
# 0            NaN   NaN                NaN                NaN          NaN
# 1            NaN   NaN                NaN                NaN          NaN
# 2      CE 10:0;0    CE                STE                STO         10.0
# 3      CE 11:0;0    CE                STE                STO         11.0
# 4      CE 12:0;0    CE                STE                STO         12.0
# ...          ...   ...                ...                ...          ...
# 2616  TAG 60:5;0   TAG                 GL                STO         60.0
# 2617  TAG 60:6;0   TAG                 GL                STO         60.0
# 2618  TAG 60:7;0   TAG                 GL                STO         60.0
# 2619  TAG 60:8;0   TAG                 GL                STO         60.0
# 2620  TAG 60:9;0   TAG                 GL                STO         60.0
#
#       totaldb  totaloh   fullname      aag2-C1      aag2-C2  ...    GPMV-V1  \
# 0         NaN      NaN  shortname       aag2C1       aag2C2  ...     GPMVV1
# 1         NaN      NaN     cohort   Aagcontrol   Aagcontrol  ...  GPMVvirus
# 2         0.0      0.0        NaN          NaN          NaN  ...        NaN
# 3         0.0      0.0        NaN          NaN          NaN  ...        NaN
# 4         0.0      0.0        NaN          NaN          NaN  ...        NaN
# ...       ...      ...        ...          ...          ...  ...        ...
# 2616      5.0      0.0        NaN  2.043479919  2.872970104  ...        NaN
# 2617      6.0      0.0        NaN   1.76880002    2.1224401  ...        NaN
# 2618      7.0      0.0        NaN  0.960611999  1.187350035  ...        NaN
# 2619      8.0      0.0        NaN          NaN          NaN  ...        NaN
# 2620      9.0      0.0        NaN          NaN          NaN  ...        NaN
#
#         GPMV-V2    GPMV-V3    GPMV-V4      U2OS-C1      U2OS-C2      U2OS-C3  \
# 0        GPMVV2     GPMVV3     GPMVV4       U2OSC1       U2OSC2       U2OSC3
# 1     GPMVvirus  GPMVvirus  GPMVvirus  U2OScontrol  U2OScontrol  U2OScontrol
# 2           NaN        NaN        NaN          NaN          NaN          NaN
# 3           NaN        NaN        NaN          NaN          NaN          NaN
# 4           NaN        NaN        NaN          NaN          NaN          NaN
# ...         ...        ...        ...          ...          ...          ...
# 2616        NaN        NaN        NaN  1.386270046  1.703940034          NaN
# 2617        NaN        NaN        NaN  1.170670033  1.122969985  0.906876028
# 2618        NaN        NaN        NaN          NaN  2.203739882   0.88359201
# 2619        NaN        NaN        NaN  1.286730051  2.046430111  1.039029956
# 2620        NaN        NaN        NaN  0.747344017  1.840209961  0.888028026
#
#           U2OS-V1      U2OS-V2      U2OS-V3
# 0          U2OSV1       U2OSV2       U2OSV3
# 1       U2OSvirus    U2OSvirus    U2OSvirus
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 2616  0.944772005  2.128760099  1.032600045
# 2617  1.265089989  2.175209999  1.203019977
# 2618   1.68919003  2.344589949   1.17990005
# 2619  1.650859952  2.308330059  1.382410049
# 2620  1.489349961  2.035140038  1.418949962
#
# [2621 rows x 40 columns]
