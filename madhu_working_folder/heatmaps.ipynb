# %% [markdown]
# # Import Data

# %%
# import modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import functions

# %%
# import raw data
df = pd.read_csv('dataframes/pos_df.csv')
df.sample(3)
# Out:
#                        Sample Name   CAS9-A  CAS9-A.1  CAS9-B  CAS9-B.1  \
# 2867             PS 40:8 (FA 22:6)  52.3981    53.762  17.548   85.8921
# 3265             PC 36:10 (PC 104)   0.0000     0.000   0.000    0.0000
# 4529  GM2 28:1;2 (LCB 17:0;2-2H2O)   0.0000    27.000   0.000    0.0000
#
#          CAV_A  CAV_A.1   CAV_B  CAV_B.1  CAVIN_A  ...  SPTLC_B  SPTLC_B.1  \
# 2867  111.9598  55.0739  82.647  79.6892      0.0  ...  93.7298   103.7511
# 3265    8.2290   0.0000   0.000   5.1612      0.0  ...   0.0000     0.0000
# 4529    0.0000   0.0000   0.000   0.0000      0.0  ...   0.0000     0.0000
#
#        UGCG-A  UGCG-A.1   UGCG-B  UGCG-B.1     WT_A   WT_A.1     WT_B  \
# 2867  26.3651   56.2266  28.7258   38.0369  55.9524  69.2572  44.7839
# 3265   0.0000    0.0000   0.0000    2.8834   0.0000   0.0000   0.0000
# 4529   0.0000    0.0000   0.0000    0.0000   0.0000   0.0000   0.0000
#
#         WT_B.1
# 2867  113.9412
# 3265    0.0000
# 4529    0.0000
#
# [3 rows x 43 columns]

# %%
# import lipid metadata
df_meta = pd.read_csv('dataframes/pos_lipids_df_meta.csv')
df_meta.sample(3)
# Out:
#                                            Sample Name Head Group  \
# 2785  Hex3Cer 48:1;2 (LCB 18:1;2-2H2O,LCB 18:0;3-3H2O)    Hex3Cer
# 2491                                   PC O-36:4 (LPC)       PC O
# 1688                    NAPE 46:7+NH4 (-FA 14:3 (NH4))       NAPE
#
#       Acyl Chain Length  Unsaturation
# 2785                 48             1
# 2491                 36             4
# 1688                 46             7

# %%
# import experiment metedata
df_exps = pd.read_csv('dataframes/pos_df_exps.csv')
df_exps.head()
# Out:
#         Exp Mutation
# 0    CAS9-A     CAS9
# 1  CAS9-A.1     CAS9
# 2    CAS9-B     CAS9
# 3  CAS9-B.1     CAS9
# 4     CAV_A      CAV

# %%
# import head group metadata
df_hg = pd.read_csv('dataframes/pos_df_hg.csv')
df_hg.head(3)
# Out:
#   Head Group Head Group 2
# 0    Hex2Cer      Hex_Cer
# 1        GT3           GT
# 2        GT2           GT

# %%
# merge df_hg and df_meta
df_meta2 = df_meta.merge(df_hg, on=['Head Group'])
df_meta2.head(1)
# Out:
#                         Sample Name Head Group  Acyl Chain Length  \
# 0  Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)    Hex2Cer                 26
#
#    Unsaturation Head Group 2
# 0             3      Hex_Cer

# %%
# rename columns by protein
df_p = df.rename(columns=df_exps.set_index('Exp')['Mutation'])
df_p = df_p.drop(columns=['RAJU'])
df_p = df_p.set_index('Sample Name')
df_p.columns.names=['Mutation']
df_p.head(5)
# Out:
# Mutation                              CAS9      CAS9      CAS9      CAS9  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  167.0000  143.0000  125.0000  132.0000
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)   53.2158   52.8015   47.4908   76.2783
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  167.8122  131.3388  220.0689  128.3439
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)    54.0000   47.0000   39.0000   44.0000
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  391.2240  326.4641  444.7720  385.3202
#
# Mutation                               CAV       CAV       CAV       CAV  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  171.6091  182.9007  120.0000  120.0000
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)   27.6563   23.0569    9.0712   24.0712
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  342.9760  331.4596  268.9979  289.4925
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)    74.0000   64.0000   84.5341   88.7361
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  175.0126  296.5953  238.6997  214.9442
#
# Mutation                             CAVIN     CAVIN  ...     SPTLC     SPTLC  \
# Sample Name                                           ...
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  281.3523  184.3462  ...  130.0000  142.0000
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)    0.0000   13.8507  ...    0.0000    2.1176
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  295.0869  224.9824  ...  290.0353  223.3067
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)    70.0000   51.0000  ...   44.0000   37.0000
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  215.1018  214.6494  ...  309.7805  272.9937
#
# Mutation                              UGCG      UGCG      UGCG      UGCG  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)   68.0529   46.4729   88.0000   91.0000
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)   47.2560   62.7063   11.1856    0.0000
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  187.9922  219.2679  231.3212  219.2373
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)    48.6404   51.9843   38.9995   52.0000
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  373.2111  292.2522  348.9607  348.3176
#
# Mutation                                WT        WT        WT        WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  229.5233  278.1255  206.0000  182.0000
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)   10.8768    6.0672    0.0000   34.4747
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  329.9421  313.2847  251.0406  226.8066
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)    62.0000   57.0000   51.0000   40.0000
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  304.3199  271.4133  303.6544  253.3654
#
# [5 rows x 40 columns]

# %% [markdown]
# # Normalize Data

# %%
# define functions to normalize down column
def norm_col(df):
    return df/df.sum()

# %%
def norm_row(df):
    return df.div(df.sum(axis=1), axis=0)

# %%
# move sample name column into index
df_norm = df_p
df_norm.head(1)
# Out:
# Mutation                           CAS9   CAS9   CAS9   CAS9       CAV  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  167.0  143.0  125.0  132.0  171.6091
#
# Mutation                               CAV    CAV    CAV     CAVIN     CAVIN  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  182.9007  120.0  120.0  281.3523  184.3462
#
# Mutation                          ...  SPTLC  SPTLC     UGCG     UGCG  UGCG  \
# Sample Name                       ...
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  ...  130.0  142.0  68.0529  46.4729  88.0
#
# Mutation                          UGCG        WT        WT     WT     WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  91.0  229.5233  278.1255  206.0  182.0
#
# [1 rows x 40 columns]

# %%
# normalize down the columns
df_norm_col = df_norm/df_norm.sum()
df_norm_col.head(1)
# Out:
# Mutation                              CAS9      CAS9      CAS9      CAS9  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.000036  0.000032  0.000025  0.000027
#
# Mutation                               CAV       CAV       CAV       CAV  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.000047  0.000051  0.000038  0.000037
#
# Mutation                            CAVIN     CAVIN  ...     SPTLC     SPTLC  \
# Sample Name                                          ...
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.00007  0.000046  ...  0.000041  0.000041
#
# Mutation                             UGCG      UGCG      UGCG      UGCG  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.00002  0.000014  0.000027  0.000027
#
# Mutation                                WT        WT        WT        WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.000048  0.000058  0.000048  0.000041
#
# [1 rows x 40 columns]

# %%
# normalize across row
df_norm_row = df_norm.div(df_norm.sum(axis=1), axis=0)
df_norm_row.head(1)
# Out:
# Mutation                              CAS9      CAS9      CAS9      CAS9  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.024047  0.020591  0.017999  0.019007
#
# Mutation                               CAV       CAV       CAV       CAV  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.024711  0.026337  0.017279  0.017279
#
# Mutation                             CAVIN     CAVIN  ...     SPTLC     SPTLC  \
# Sample Name                                           ...
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.040513  0.026545  ...  0.018719  0.020447
#
# Mutation                              UGCG      UGCG      UGCG      UGCG  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.009799  0.006692  0.012672  0.013104
#
# Mutation                               WT        WT        WT        WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.03305  0.040049  0.029663  0.026207
#
# [1 rows x 40 columns]

# %%
# normalize across both row & col
df_norm = df_norm_col.div(df_norm_col.sum(axis=1), axis=0)
df_norm.head(1)
# Out:
# Mutation                              CAS9    CAS9      CAS9      CAS9  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.019506  0.0171  0.013386  0.014721
#
# Mutation                               CAV       CAV       CAV       CAV  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.025627  0.027595  0.020395  0.020296
#
# Mutation                             CAVIN     CAVIN  ...     SPTLC     SPTLC  \
# Sample Name                                           ...
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.037756  0.024928  ...  0.022295  0.022394
#
# Mutation                              UGCG      UGCG      UGCG      UGCG  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.010866  0.007405  0.014582  0.014583
#
# Mutation                                WT        WT        WT       WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.026141  0.031296  0.025874  0.02239
#
# [1 rows x 40 columns]

# %% [markdown]
# # Average/groupby protein

# %%
# normalized by row & col
df_norm_avg = df_norm.T.reset_index().rename(columns={'index':'Mutation'})
df_norm_avg = df_norm_avg.groupby('Mutation').mean().T
df_norm_avg.head()
# Out:
# Mutation                              CAS9       CAV     CAVIN  CERS2-1g  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.016179  0.023478  0.029077  0.031709
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.064624  0.032709  0.012293  0.013645
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.012212  0.032689  0.022299  0.025387
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.017766  0.042347  0.021723  0.029091
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.029658  0.025001  0.020187  0.020504
#
# Mutation                          CERS2_mg     CERS5     Flot2     SPTLC  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.029220  0.031893  0.029489  0.020671
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.011860  0.020105  0.029636  0.001913
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.029948  0.028250  0.024203  0.029847
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.023994  0.029493  0.015644  0.022888
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.023521  0.020142  0.018196  0.032862
#
# Mutation                              UGCG        WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.011859  0.026425
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.047969  0.015246
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.023096  0.022069
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.026081  0.020971
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.037178  0.022752

# %%
# normalized by row only
df_norm_row_avg = df_norm_row.T.reset_index().rename(columns={'index':'Mutation'})
df_norm_row_avg = df_norm_row_avg.groupby('Mutation').mean().T
df_norm_row_avg.head()
# Out:
# Mutation                              CAS9       CAV     CAVIN  CERS2-1g  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.020411  0.021402  0.031956  0.028405
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.078368  0.028599  0.013087  0.011465
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.015926  0.030322  0.025096  0.023253
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.022769  0.038518  0.024130  0.026532
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.037998  0.022715  0.022420  0.018439
#
# Mutation                          CERS2_mg     CERS5     Flot2     SPTLC  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.027034  0.033241  0.027860  0.016882
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.010702  0.019837  0.027584  0.001504
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.028544  0.030185  0.023401  0.024605
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.022645  0.031431  0.015468  0.018809
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.021945  0.021170  0.017250  0.026798
#
# Mutation                              UGCG        WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.010567  0.032242
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.041317  0.017536
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.021097  0.027571
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.023712  0.025986
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.033455  0.027809

# %%
# normalized by row only
df_norm_col_avg = df_norm_col.T.reset_index().rename(columns={'index':'Mutation'})
df_norm_col_avg = df_norm_col_avg.groupby('Mutation').mean().T
df_norm_col_avg.head()
# Out:
# Mutation                              CAS9       CAV     CAVIN  CERS2-1g  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.000030  0.000043  0.000054  0.000058
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.000012  0.000006  0.000002  0.000003
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.000034  0.000090  0.000062  0.000070
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.000010  0.000023  0.000012  0.000016
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.000081  0.000068  0.000055  0.000056
#
# Mutation                          CERS2_mg     CERS5     Flot2         SPTLC  \
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.000054  0.000059  0.000054  3.811926e-05
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.000002  0.000004  0.000006  3.565203e-07
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.000083  0.000078  0.000067  8.246657e-05
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.000013  0.000016  0.000009  1.247975e-05
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.000064  0.000055  0.000050  8.957203e-05
#
# Mutation                              UGCG        WT
# Sample Name
# Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)  0.000022  0.000049
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.000009  0.000003
# Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)  0.000064  0.000061
# Hex2Cer 26:2;2 (LCB 18:0;2-H2O)   0.000014  0.000011
# Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)  0.000101  0.000062

# %% [markdown]
# # Correlation Matrix, whole dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_corr = df_norm_avg.corr()

# %%
sns.heatmap(df_corr, vmin=-1.0,vmax=1.0, cmap='RdBu')
# Out:
# <Axes: xlabel='Mutation', ylabel='Mutation'>

# %% [markdown]
# # Clustermap, whole dataset

# %%
sns.clustermap(df_norm_row_avg.iloc[:29], cmap='Reds')

# %% [markdown]
# # Correlation matrix

# %%
'''
Returns the correlation matrix for a dataset when comparing by specific proteins.
Data is normalized by column and row. 

Inputs:
df_meta: df with lipid metadata (sample, head group, chain length, unsaturation)
df_p: df with columns named by mutation, rather than individual experiments
col: column name for variable of interest (ex: head group 2)
drop_var: variable of interest (row) to be dropped (ex: head group PE)
drop_protein: mutation (column) to be dropped (ex: WT)
title: title of graph, string
annot: include annotations, takes True or False
'''
def corr_matrix(df_meta, df_p, col, drop_var=[], drop_protein=[], title='Correlation Matrix', annot=False):
    # create merged df with variable of interest
    df = df_meta[['Sample Name', col]].merge(df_p, on='Sample Name').set_index('Sample Name')
    
    # drop rows and columns
    if drop_var != []:
        df = df[~df[col].isin(drop_var)]
        
    if drop_protein != []:
        df = df.drop(columns=drop_protein)
    
    # group by variable of interest
    df = df.groupby(col).sum()
    # normalize by the sample
    df = norm_col(df)
    
    # name columns so that we can group by them once transposed
    df.columns.names=['Mutation']
    # transpose and then find the average value for each protein
    df = df.T.groupby('Mutation').mean()
    
    # normalize by the variable (column)
    df = norm_col(df)
    
    # transpose again so proteins are columns, then run a correlation matrix
    corr = df.T.corr()
    
    sns.heatmap(corr, vmin=-1, vmax=1, cmap='RdYlGn', annot=annot).set_title(title)

# %%
corr_matrix(df_meta2, df_p, 
            col='Acyl Chain Length', 
            drop_protein=['WT'], 
            title='Correlation Matrix when Comparing Acyl Chain Lengths'
           )

# %%
corr_matrix(df_meta2, df_p, 
            col='Head Group 2', 
            drop_var=['PE', 'PC'],
            drop_protein=['WT'], 
            title='Correlation Matrix when Comparing Head Groups'
           )

# %%
corr_matrix(df_meta2, df_p, 
            col='Unsaturation', 
            drop_protein=['WT'], 
            title='Correlation Matrix when Comparing Unsaturation'
           )

# %% [markdown]
# # Clustermap of correlation matrix

# %%
'''
Returns the correlation matrix sorted by similarity (clustered) for a dataset when comparing by specific proteins
Data is normalized by column and row

Inputs:
df_meta: df with lipid metadata (sample, head group, chain length, unsaturation)
df_p: df with columns named by mutation, rather than individual experiments
col: column name for variable of interest (ex: head group 2)
drop_var: list variable of interests (rows) to be dropped (ex: head group PE)
drop_protein: list of mutations (columns) to be dropped (ex: WT)
title: title of graph, string
annot: include annotations, takes True or False
'''
def cluster_matrix(df_meta, df_p, col, drop_var=[], drop_protein=[], title='Correlation Matrix', annot=False):
    # create merged df with variable of interest
    df = df_meta[['Sample Name', col]].merge(df_p, on='Sample Name').set_index('Sample Name')
    
    # drop rows and columns
    if drop_var != []:
        df = df[~df[col].isin(drop_var)]
        
    if drop_protein != []:
        df = df.drop(columns=drop_protein)
    
    # group by variable of interest
    df = df.groupby(col).sum()
    # normalize by the sample
    df = norm_col(df)
    
    # name columns so that we can group by them once transposed
    df.columns.names=['Mutation']
    # transpose and then find the average value for each protein
    df = df.T.groupby('Mutation').mean()
    
    # normalize by the variable (column)
    df = norm_col(df)
    
    # transpose again so proteins are columns, then run a correlation matrix
    corr = df.T.corr()
    
    sns.set(rc={"figure.facecolor": "white"})
    sns.clustermap(corr, vmin=-1, vmax=1, cmap='RdYlGn', annot=annot).fig.suptitle(title, y=1.05)

# %%
cluster_matrix(df_meta2, df_p, 
            col='Acyl Chain Length', 
            drop_protein=['WT'], 
            title='Correlation Matrix when Comparing Acyl Chain Lengths'
           )
# plt.savefig('graphs/pos_mode_whole_dataset/chain_length_graphs/updated_HeadGroupCorr_Heatmap_WithPS.png', dpi=300)

# %%
cluster_matrix(df_meta2, df_p, 
            col='Head Group 2', 
            drop_var=['PE', 'PC'],
            drop_protein=['WT'], 
            title='Correlation Matrix when Comparing Head Groups'
           )
# plt.savefig('graphs/pos_mode_whole_dataset/head_group_graphs/updated_HeadGroupCorr_Heatmap_WithPS.png', dpi=300)

# %%
cluster_matrix(df_meta2, df_p, 
            col='Unsaturation', 
            drop_protein=['WT'], 
            title='Correlation Matrix when Comparing Unsaturation'
           )
# plt.savefig('graphs/pos_mode_whole_dataset/unsaturation_graphs/updated_UnsaturationCorr_Heatmap_WithPS.png', dpi=300)

# %% [markdown]
# # Heatmaps

# %%
'''
Returns heatmap, with values normalized down the column
'''
def heatmap_norm_col(df_meta, df_p, col, drop_var=[], drop_protein=[], title='Heatmap', annot=False):
    # create merged df with variable of interest
    df = df_meta[['Sample Name', col]].merge(df_p, on='Sample Name').set_index('Sample Name')
    
    # drop rows and columns
    if drop_var != []:
        df = df[~df[col].isin(drop_var)]
        
    if drop_protein != []:
        df = df.drop(columns=drop_protein)
    
    # group by variable of interest
    df = df.groupby(col).sum()
    # normalize by the mutation
    df = norm_col(df)
    
    # name columns so that we can group by them once transposed
    df.columns.names=['Mutation']
    # transpose and then find the average value for each protein
    df = df.T.groupby('Mutation').mean()
    
    # transpose so that mutations are in columns again
    df = df.T
    
    sns.set(rc={"figure.facecolor": "white"})
    sns.clustermap(df, vmin=0, vmax=1, cmap='Reds', annot=annot).fig.suptitle(title, y=1.05)

# %%
heatmap_norm_col(df_meta2,
        df_p,
        col='Head Group 2',
        drop_var=['PE', 'PC'],
        drop_protein=['WT'],
        title='Heatmap of Head Groups, Normalized by Mutation'
       )

# %%
heatmap_norm_col(df_meta2,
        df_p,
        col='Acyl Chain Length',
        drop_protein=['WT'],
        title='Heatmap of Chain Lengths, Normalized by Mutation'
       )

# %%
heatmap_norm_col(df_meta2,
        df_p,
        col='Unsaturation',
        drop_protein=['WT'],
        title='Heatmap of Unsaturation, Normalized by Mutation'
       )

# %%
'''
Returns heatmap with values normalized by row
'''
def heatmap_norm_row(df_meta, df_p, col, drop_var=[], drop_protein=[], title='Heatmap', annot=False):
    # create merged df with variable of interest
    df = df_meta[['Sample Name', col]].merge(df_p, on='Sample Name').set_index('Sample Name')
    
    # drop rows and columns
    if drop_var != []:
        df = df[~df[col].isin(drop_var)]
        
    if drop_protein != []:
        df = df.drop(columns=drop_protein)
    
    # group by variable of interest
    df = df.groupby(col).sum()
    
    # name columns so that we can group by them once transposed
    df.columns.names=['mutation']
    # transpose and then find the average value for each protein
    df = df.T.groupby('mutation').mean()
    
    # transpose so that mutations are in columns again
    df = df.T
    df = norm_row(df)
    # print(df.sum(axis=1))
    
    sns.set(rc={"figure.facecolor": "white"})
    sns.clustermap(df, vmin=0, vmax=1, cmap='Reds', annot=annot).fig.suptitle(title, y=1.05)

# %%
heatmap_norm_row(df_meta2,
                 df_p,
                 col='Head Group 2',
                 drop_var=['PE', 'PC'],
                 drop_protein=['WT'],
                 title='Heatmap of Head Groups, Normalized by Head Group'
                )

# %%
heatmap_norm_row(df_meta2,
        df_p,
        col='Acyl Chain Length',
        drop_protein=['WT'],
        title='Heatmap of Chain Lengths, Normalized by Chain Length'
       )

# %%
heatmap_norm_row(df_meta2,
                 df_p,
                 col='Unsaturation',
                 drop_protein=['WT'],
                 title='Heatmap of Unsaturation, Normalized by Unsaturation',
                )

# %%
'''
Returns heatmap, with values normalized by both column and row
'''
def heatmap_norm(df_meta, df_p, col, drop_var=[], drop_protein=[], title='Heatmap', annot=False):
    # create merged df with variable of interest
    df = df_meta[['Sample Name', col]].merge(df_p, on='Sample Name').set_index('Sample Name')
    
    # drop rows and columns
    if drop_var != []:
        df = df[~df[col].isin(drop_var)]
        
    if drop_protein != []:
        df = df.drop(columns=drop_protein)
    
    # group by variable of interest
    df = df.groupby(col).sum()
    # normalize by the mutation
    df = norm_col(df)
    
    # name columns so that we can group by them once transposed
    df.columns.names=['Mutation']
    # transpose and then find the average value for each protein
    df = df.T.groupby('Mutation').mean()
    
    # transpose so that mutations are in columns again
    df = df.T
    # normalize by the variable (row)
    df = norm_row(df)
    # print(df.sum(axis=1))
    
    sns.set(rc={"figure.facecolor": "white"})
    sns.clustermap(df, vmin=0, vmax=1, cmap='Reds', annot=annot).fig.suptitle(title, y=1.05)

# %%
heatmap_norm(df_meta2,
        df_p,
        col='Head Group 2',
        drop_var=['PE', 'PC'],
        drop_protein=['WT'],
        title='Heatmap of Head Groups, Normalized by Mutation and Head Group'
       )

# %%
heatmap_norm(df_meta2,
        df_p,
        col='Acyl Chain Length',
        drop_protein=['WT'],
        title='Heatmap of Chain Lengths, Normalized by Mutation and Chain Length'
       )

# %%
heatmap_norm_row(df_meta2,
                 df_p,
                 col='Unsaturation',
                 drop_protein=['WT'],
                 title='Heatmap of Unsaturation, Normalized by Mutation and Unsaturation',
                )

# %% [markdown]
# # Heatmaps without row clustering

# %%
# import functions
import functions

# %% [markdown]
# ### Acyl Chain Length

# %% [markdown]
# #### Acyl Chain Length, Evens

# %%
df_cl = functions.groupby_norm(df_meta2, 
                               df_p,
                               var='Acyl Chain Length',
                               drop_var=list(range(1,70,2)),
                               drop_mutation=['WT'])

# %%
sns.set(rc={"figure.facecolor": "white"})
sns.clustermap(df_cl, row_cluster=False, cmap='Reds').fig.suptitle('Heatmap of Chain Lengths, Normalized by Mutation and Chain Length', y=1.05)
# Out:
# Text(0.5, 1.05, 'Heatmap of Chain Lengths, Normalized by Mutation and Chain Length')

# %% [markdown]
# #### Acyl Chain Length, Odds

# %%
df_cl_o = functions.groupby_norm(df_meta2, 
                                 df_p, 
                                 var='Acyl Chain Length', 
                                 drop_var=list(range(0,70,2)), 
                                 drop_mutation=['WT'])

# %%
sns.set(rc={"figure.facecolor": "white"})
sns.clustermap(df_cl_o, row_cluster=False, cmap='Reds').fig.suptitle('Heatmap of Odd Chain Lengths, Normalized by Mutation and Chain Length', y=1.05)
# Out:
# Text(0.5, 1.05, 'Heatmap of Odd Chain Lengths, Normalized by Mutation and Chain Length')

# %% [markdown]
# ### Unsaturation

# %%
df_u = functions.groupby_norm(df_meta, df_p, var='Unsaturation', drop_mutation=['WT'])
df_u
# Out:
# Mutation          CAS9       CAV     CAVIN  CERS2-1g  CERS2_mg     CERS5  \
# Unsaturation
# 0             0.099649  0.100077  0.098056  0.114639  0.123641  0.117416
# 1             0.105985  0.106559  0.107304  0.120766  0.122091  0.123930
# 2             0.112880  0.107518  0.110806  0.112632  0.114917  0.116835
# 3             0.108747  0.106039  0.123815  0.115036  0.098845  0.102460
# 4             0.105707  0.139490  0.103947  0.100760  0.094874  0.087360
# 5             0.116541  0.132569  0.111025  0.098995  0.100004  0.089121
# 6             0.141487  0.100542  0.110273  0.096501  0.097258  0.109691
# 7             0.117179  0.095368  0.108986  0.107783  0.130142  0.129542
# 8             0.111241  0.087925  0.139962  0.106160  0.102886  0.110463
# 9             0.163117  0.091959  0.173682  0.087797  0.079015  0.098898
# 10            0.141162  0.111276  0.154479  0.100412  0.084807  0.103994
# 11            0.101394  0.123596  0.131403  0.115680  0.103115  0.100457
# 12            0.055650  0.183980  0.120309  0.117144  0.098313  0.124187
#
# Mutation         Flot2     SPTLC      UGCG
# Unsaturation
# 0             0.111268  0.116177  0.119078
# 1             0.117789  0.090590  0.104988
# 2             0.115799  0.107730  0.100882
# 3             0.111201  0.118961  0.114898
# 4             0.094953  0.149054  0.123855
# 5             0.099545  0.140172  0.112029
# 6             0.115354  0.112978  0.115916
# 7             0.121103  0.095063  0.094834
# 8             0.131125  0.059627  0.150611
# 9             0.104044  0.069578  0.131909
# 10            0.098329  0.103904  0.101637
# 11            0.090453  0.141175  0.092727
# 12            0.083890  0.124643  0.091885

# %%
sns.set(rc={"figure.facecolor": "white"})
sns.clustermap(df_u, row_cluster=False, cmap='Reds').fig.suptitle('Heatmap of Unsaturation, Normalized by Mutation and Unsaturation', y=1.05)
# Out:
# Text(0.5, 1.05, 'Heatmap of Unsaturation, Normalized by Mutation and Unsaturation')

# %% [markdown]
# #### Unsaturation, grouped

# %%
# group unsaturation
import numpy as np
df_meta2['Unsaturation 2'] = np.where(df_meta2['Unsaturation'] < 3, df_meta2['Unsaturation'], '>=3')
df_meta2.head()
# Out:
#                         Sample Name Head Group  Acyl Chain Length  \
# 0  Hex2Cer 26:3;2 (LCB 18:0;2-2H2O)    Hex2Cer                 26
# 1  Hex2Cer 26:2;2 (LCB 18:0;2-2H2O)    Hex2Cer                 26
# 2   Hex2Cer 26:2;2 (LCB 18:0;2-H2O)    Hex2Cer                 26
# 3  Hex2Cer 26:0;2 (LCB 18:0;2-2H2O)    Hex2Cer                 26
# 4   Hex2Cer 26:0;2 (LCB 18:0;2-H2O)    Hex2Cer                 26
#
#    Unsaturation Head Group 2 Unsaturation 2
# 0             3      Hex_Cer            >=3
# 1             2      Hex_Cer              2
# 2             2      Hex_Cer              2
# 3             0      Hex_Cer              0
# 4             0      Hex_Cer              0

# %%
df_u2 = functions.groupby_norm(df_meta2, df_p, var='Unsaturation 2', drop_mutation=['WT'])
df_u2
# Out:
# Mutation            CAS9       CAV     CAVIN  CERS2-1g  CERS2_mg     CERS5  \
# Unsaturation 2
# 0               0.099649  0.100077  0.098056  0.114639  0.123641  0.117416
# 1               0.105985  0.106559  0.107304  0.120766  0.122091  0.123930
# 2               0.112880  0.107518  0.110806  0.112632  0.114917  0.116835
# >=3             0.117591  0.119601  0.118223  0.102700  0.097689  0.097641
#
# Mutation           Flot2     SPTLC      UGCG
# Unsaturation 2
# 0               0.111268  0.116177  0.119078
# 1               0.117789  0.090590  0.104988
# 2               0.115799  0.107730  0.100882
# >=3             0.104340  0.124821  0.117394

# %%
sns.set(rc={"figure.facecolor": "white"})
sns.clustermap(df_u2, row_cluster=False, cmap='Reds').fig.suptitle('Heatmap of Unsaturation, Normalized by Mutations and Unsaturation', y=1.05)
# Out:
# Text(0.5, 1.05, 'Heatmap of Unsaturation, Normalized by Mutations and Unsaturation')

# %% [markdown]
# # Bubble Heatmap

# %%
def extract_clustered_table(res, data):
    """
    input
    =====
    res:     <sns.matrix.ClusterGrid>  the clustermap object
    data:    <pd.DataFrame>            input table
    
    output
    ======
    returns: <pd.DataFrame>            reordered input table
    """
    
    # if sns.clustermap is run with row_cluster=False:
    if res.dendrogram_col is None:
        print("Apparently, columns were not clustered.")
        return -1
#     
    if res.dendrogram_row is not None:
        # reordering index and columns
        new_cols = data.columns[res.dendrogram_col.reordered_ind]
        new_ind = data.index[res.dendrogram_row.reordered_ind]
        
        return data.loc[new_ind, new_cols]
    
    else:
        # reordering the columns
        new_cols = data.columns[res.dendrogram_col.reordered_ind]

        return data.loc[:,new_cols]

# %%
# umap = sns.clustermap(df_u2, row_cluster=False, cmap='Reds', annot=True)

# %%
# u_ordered = extract_clustered_table(umap, df_u2)
# u_ordered.head()

# %%
# ul = u_ordered.reset_index().melt('Unsaturation 2')
# import altair as alt

# b = alt.Chart(ul).mark_rect(stroke='lightgray', fill=None).encode(
#     x = alt.X('Mutation:N', sort=None),
#     y = 'Unsaturation 2:O',
# ).properties(
#     width=800,
#     height=500,
#     title= 'Heatmap of Unsaturation, Normalized by Mutations and Unsaturation'
# )

# c = alt.Chart(ul).mark_circle().encode(
#     x = alt.X('Mutation:N', sort=None),
#     y = alt.Y('Unsaturation 2:O').title('Unsaturation'),
#     size=alt.Size('value:Q').scale(domain=[min(ul['value']), max(ul['value'])], range=[1000,6500]).legend(None),
#     color=alt.Color('value:Q').scale(scheme='lightgreyred', domain=(min(ul['value']), max(ul['value']))).legend(title='Fraction')
# )

# (b+c).configure(background='white')

# %%
def bubble_heatmap(res, data, var_type, cmap='yellowgreenblue', cmap_domain=[]):
    import altair as alt 
    
    # get ordered table
    res_ordered = extract_clustered_table(res, data)
    
    # get variable name and axis title
    var = res_ordered.index.name
    var_title = var.rsplit(' ', 1)[0]
    
    # create long form of data
    l = res_ordered.reset_index().melt(var, value_name='Fraction')
    
    # get domain for cmap
    if cmap_domain == []:
        cmap_domain = [min(l['Fraction']), max(l['Fraction'])]
    
    # create grid for heatmap
    b = alt.Chart(l).mark_rect(stroke='lightgray', fill=None).encode(
        x = alt.X('Mutation:N', sort=None),
        y = alt.Y(var, type=var_type, sort=None)
    ).properties(
        width=800,
        height= ((800/len(res_ordered.columns)) * len(res_ordered.index)),
        title= 'Heatmap of {var_name}, Normalized by Mutations and {var_name}'.format(var_name=var_title)   
    )
      
    # create bubbles for heatmap
    c = alt.Chart(l).mark_circle().encode(
        x = alt.X('Mutation:N', sort=None),
        y = alt.Y(var, type=var_type, sort=None).title(var_title),
        size=alt.Size('Fraction:Q').scale(domain=cmap_domain, range=[1000,6500]),
        color=alt.Color('Fraction:Q').scale(scheme=cmap, domain=cmap_domain),
        tooltip=['Mutation', var, 'Fraction']
    ) 
    
    return (b+c).configure(background='white')

# %%
# cmap = sns.clustermap(df_cl, row_cluster=False, cmap='Reds')

# %%
# df_h = functions.groupby_norm(df_meta2, 
#                                df_p,
#                                var='Head Group 2',
#                                drop_mutation=['WT'])

# %%
# hmap = sns.clustermap(df_h, cmap='Reds')

# %%
# # get ordered table
# res_ordered = extract_clustered_table(cmap, df_cl)
    
# # create long form of data
# l = res_ordered.reset_index().melt(var)
    
# # create grid for heatmap
# b = alt.Chart(l).mark_rect(stroke='lightgray', fill=None).encode(
#     x = alt.X('Mutation:N', sort=None),
#     y = alt.Y('Acyl Chain Length:O')
# ).properties(
#     title= 'Heatmap of Acyl Chain Length, Normalized by Mutations and Acyl Chain Length',
#     width = 800,
#     height = 2222
# )
      
# # create bubbles for heatmap
# c = alt.Chart(l).mark_circle().encode(
#     x = alt.X('Mutation:N', sort=None),
#     y = alt.Y('Acyl Chain Length:O').title('Acyl Chain Length'),
#     size=alt.Size('value:Q').scale(domain=[min(l['value']), max(l['value'])], range=[1000,6500]).legend(None),
#     color=alt.Color('value:Q').scale(scheme='lightgreyred', domain=(min(l['value']), max(l['value']))).legend(title='Fraction')
# )
    
# (b+c).configure(background='white')

# %%
# bubble_heatmap(cmap, df_cl, var_type='ordinal', cmap_domain=[0,1])

# %%
# bubble_heatmap(umap, df_u2, var_type='ordinal')

# %%
# bubble_heatmap(hmap, df_h, 'nominal', cmap='yellowgreenblue', cmap_domain=[0,1])

# %%
df_cl = functions.groupby_norm(df_meta2, 
                     df_p, 
                     var='Acyl Chain Length', 
                     drop_var=list(range(1, 70, 2)), 
                     drop_mutation = ['WT'],
                     norm_var=False
                    )

# %%
sns.set(rc={"figure.facecolor": "white"})
cmap = sns.clustermap(df_cl, row_cluster=False, cmap='YlGnBu').fig.suptitle('Heatmap of Acyl Chain Length, Normalized by Mutation', y=1.05)

# %%
cmap = sns.clustermap(df_cl, row_cluster=False, cmap='YlGnBu')

# %%
functions.bubble_heatmap(cmap, df_cl, var_type='ordinal', title='Heatmap of Acyl Chain Length, Normalized by Mutation')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %%
df_h = functions.groupby_norm(df_meta2, 
                     df_p, 
                     var='Head Group 2', 
                     drop_mutation = ['WT'],
                     norm_var=False
                    )

# %%
sns.set(rc={"figure.facecolor": "white"})
hmap = sns.clustermap(df_h, cmap='YlGnBu').fig.suptitle('Heatmap of Head Group, Normalized by Mutation', y=1.05)

# %%
hmap = sns.clustermap(df_h, cmap='YlGnBu')

# %%
functions.bubble_heatmap(hmap, df_h, var_type='nominal', title='Heatmap of Head Groups, Normalized by Mutation')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %%
df_u = functions.groupby_norm(df_meta2, 
                     df_p, 
                     var='Unsaturation 2',
                     drop_mutation = ['WT'],
                     norm_var=False
                    )

# %%
sns.set(rc={"figure.facecolor": "white"})
umap = sns.clustermap(df_u, row_cluster=False, cmap='YlGnBu').fig.suptitle('Heatmap of Unsaturation, Normalized by Mutation', y=1.05)

# %%
umap = sns.clustermap(df_u, row_cluster=False, cmap='YlGnBu')

# %%
functions.bubble_heatmap(umap, df_u, var_type='ordinal', title='Heatmap of Unsaturation, Normalized by Mutation')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %% [markdown]
# # Fold Change from CAS9

# %%
cl_fold, clmax, clmin = functions.fold_change(df_meta2,
                               df_p,
                               var='Acyl Chain Length',
                               mtn='CAS9',
                               drop_var=list(range(1,70,2)),
                               drop_mutation=['WT'],
                               row_cluster=False)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
cl_fold, clmax, clmin = functions.fold_change(df_meta2,
                               df_p,
                               var='Acyl Chain Length',
                               mtn='CAS9',
                               drop_var=list(range(1,70,2)),
                               drop_mutation=['WT'],
                               row_cluster=False,
                               outlier=False)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
u_fold, umax, umin = functions.fold_change(df_meta2,
                               df_p,
                               var='Unsaturation 2',
                               renamed_var='Unsaturation',
                               mtn='CAS9',
                               drop_mutation=['WT'],
                               row_cluster=False)

# %%
h_fold, hmax, hmin = functions.fold_change(df_meta2,
                                           df_p,
                                           var='Head Group 2',
                                           renamed_var='Head Group',
                                           mtn='CAS9',
                                           drop_mutation=['WT'],
                                           row_cluster=True,
                                           cbar_args={'vmax' : 2, 'tmax': 2}
                                          )

# %%
h_fold, hmax, hmin = functions.fold_change(df_meta2,
                                           df_p,
                                           var='Head Group 2',
                                           renamed_var='Head Group',
                                           mtn='CAS9',
                                           drop_mutation=['WT'],
                                           row_cluster=True,
                                           outlier=False,
                                           cbar_args={'vmax' : 2, 'tmax': 2}
                                          )

# %%
h_fold_map = sns.clustermap(h_fold, row_cluster=False, cmap='RdBu')

# %%
functions.bubble_heatmap(h_fold_map, h_fold, var_type='nominal', title='log(Fold Change from CAS9)', cmap='purplegreen', cmap_domain=[-1.5, 1.5])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %% [markdown]
# # Z-Score:
#
# (mean1 - mean2)/(sqrt(SE1^2 + SE2^2))
#
# x1 = col, x2 = control

# %%
var = 'Head Group 2'
norm_exp=True
drop_var=[]
drop_mutation=['WT']
renamed_var='Head Group'
ctrl = 'CAS9'
outlier=True
row_cluster=True
cbar_args={}

# import modules
import numpy as np
import matplotlib
import seaborn as sns

# create merged df with variable of interest
df = df_meta2[['Sample Name', var]].merge(df_p, on='Sample Name').set_index('Sample Name')

# group by variable of interest
df = df.groupby(var).sum()

# normalize by the experiment (down the columns)
if norm_exp:
    df = norm_col(df)

# drop rows and columns
if drop_var != []:
    df = df[~df.index.isin(drop_var)]
if drop_mutation != []:
    df = df.drop(columns=drop_mutation)

# name columns so that we can group by them once transposed
df.columns.names = ['Mutation']
# rename index
if renamed_var != '':
    df.index.names = [renamed_var]
    var = renamed_var

# transpose and then find the average value & standard error 
dfm = df.T.groupby('Mutation').mean().T
dfm.head()

# find standard error for each mutation
dfse = df.T.groupby('Mutation').sem().T
dfse.head()

# calculate z-score
dfm = dfm.sub(dfm[ctrl], axis=0) # numerator
dfse = dfse ** 2 # denominator
dfse = np.sqrt(dfse.add(dfse[ctrl], axis=0))
dfz = dfm/dfse

# dfz formatting
dfz.fillna(1, inplace=True) # replace NaN (0/0) with 1
non_inf_max = max(dfz[dfz != np.inf].max())    # find max fold chage to replace infinities
non_inf_min = min(dfz[dfz != -np.inf].min())    # find minimum
if outlier:
    df.replace(np.inf, non_inf_max **10, inplace=True)    # replace pos infinities with obvious outlier
    df.replace(-np.inf, non_inf_min*10, inplace=True)    # replace neg inf with obvious outlier
else:
    df.replace(np.inf, non_inf_max, inplace=True)    # replace pos infinities with max
    df.replace(-np.inf, non_inf_min, inplace=True)    # replace neg inf with minimum


# plot heatmap -- get colormap
cmap = matplotlib.colormaps['PRGn']    # set colormap
cmap.set_over('blue')    # add color for pos outliers
cmap.set_under('red')    # add color for neg outliers

# get args for colorbar
cbar = {}
cbar['vmax'] = non_inf_max
cbar['vmin'] = non_inf_min
cbar['tmin'] = functions.truncate(cbar['vmin'])
cbar['tmax'] = functions.truncate(cbar['vmax'])

# replace with manual oversets if given
for key in cbar_args.keys():
    cbar[key] = cbar_args[key]

# set cbar args
vmin=cbar['vmin']
vmax=cbar['vmax']
norm = matplotlib.colors.TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)    # set center of colorbar at 0
ticks = [cbar['tmin'], cbar['tmin']/2, 0, cbar['tmax']/2, cbar['tmax']]    # set colorbar ticks
cbar_kws = {'ticks' : ticks}
if outlier:
    cbar_kws['extend'] = 'both'

# plot heatmap
sns.set(sns.set(rc={"figure.facecolor": "white"}))    # add background color for graph
sns.clustermap(
    dfz, 
    cmap=cmap,
    norm=norm,
    cbar=True, cbar_kws=cbar_kws, 
    vmin=vmin, 
    vmax=vmax, 
    row_cluster=row_cluster, 
).fig.suptitle(
        'Heatmap of {var_name}, Z-Score Compared to CAS9)'.format(var_name=var), 
        y=1.05
)
# Out:
# Text(0.5, 1.05, 'Heatmap of Head Group, log(Fold Change from CAS9)')

# %%
import altair as alt

source = dfz.reset_index().melt('Head Group', value_name='Z-Score')

alt.Chart(source).mark_rect().encode(
    x='Mutation:N',
    y='Head Group:N',
    color=alt.Color('Z-Score:Q').scale(scheme='purplegreen', domainMid=0),
    tooltip=['Mutation', 'Head Group', 'Z-Score']
).properties(
    height=500,
    width=500,
    title={'text':'Head Group Z-Scores', 'subtitle':'Compared to CAS9'}
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
