# %% [markdown]
# # Columns
# 1) input: list of all columns + group (metadata)
# 2) df.drop(df.columns not in input_columns)
#
# questions:
# - how to know which column/row in metadata table has column names? if column metadata >2 columns? specify format?
#
#
# Flow:
# 1) submit dataframe
# 2) optional: submit header
# 3) optional: submit lipid categories
# 4) how many column levels?
#     4a) which column level would you like to use for table?
# 5) how many index levels (columns about lipids?)
#     5a) which column contains individual lipid species?
# 6) which columns/indices would you like to drop?
#     6a)

# %%
import pandas as pd
header = pd.read_csv('data/csv/dgat/a1_header.csv')
header.T
# hT = header.T
# hT.columns = hT.iloc[0]
# hT = hT[1:]
# hT
# Out:
#                           0           1
# shortname          fullname      cohort
# 63          VilERT-G519R-63       G519R
# 73            VilERT-M5B-73         iKO
# 76            VilERT-M5B-76         iKO
# 80          VilERT-G519R-80       G519R
# 83          VilERT-G519R-83       G519R
# 86          VilERT-G519R-86     Control
# 89          VilERT-G519R-89         iKO
# 93          VilERT-G519R-93         iKO
# 94          VilERT-G519R-94     Control
# 108        VilERT-G519R-108       G519R
# 110        VilERT-G519R-110     Control
# 112        VilERT-G519R-112     Control
# 116        VilERT-G519R-116       G519R
# 117        VilERT-G519R-117     Control
# 195            Lrig-M5B-195         iKO
# 196            Lrig-M5B-196         iKO
# 248           Lrig1-M5B-248    Lrig1-D3
# 249           Lrig1-M5B-249    Lrig1-D3
# 255           Lrig1-M5B-255    Lrig1-D3
# 257           Lrig1-M5B-257    Lrig1-D3
# ALI                 H655ALI    DGAT-ALI
# Lipid             H655Lipid  DGAT-Lipid

# %%
df_a1 = pd.read_csv('data/csv/dgat/a1_pmol.csv')
df_a1.set_index(list(df_a1.columns[:3]), inplace=True)
df_a1.columns = [list(df_a1.columns), list(df_a1.iloc[0]), list(df_a1.iloc[1])]
df_a1 = df_a1.droplevel('Unnamed: 0', axis=0)
df_a1 = df_a1[2:]
df_a1
# Out:
#                                86              94              110  \
#                   VilERT-G519R-86 VilERT-G519R-94 VilERT-G519R-110
#                           Control         Control          Control
# feature     class
# CE 13:0;0   CE                NaN             NaN              NaN
# CE 16:0;0   CE        55.57350159     30.77109909      18.34740067
# CE 16:1;0   CE        7.007959843       4.1386199      2.512140036
# CE 17:0;0   CE                NaN     3.202250004              NaN
# CE 18:0;0   CE         18.3281002     12.43249989      5.665629864
# ...                           ...             ...              ...
# TAG 62:11;0 TAG               NaN             NaN              NaN
# TAG 62:12;0 TAG               NaN     0.875769973              NaN
# TAG 62:13;0 TAG               NaN     0.726455986              NaN
# TAG 62:14;0 TAG        1.83307004     0.747078001              NaN
# TAG 62:15;0 TAG               NaN             NaN              NaN
#
#                                112              117      Control  \
#                   VilERT-G519R-112 VilERT-G519R-117          NaN
#                            Control          Control      Average
# feature     class
# CE 13:0;0   CE                 NaN              NaN            0
# CE 16:0;0   CE         10.03540039      19.29459953  26.80440025
# CE 16:1;0   CE                 NaN              NaN  4.552906593
# CE 17:0;0   CE                 NaN              NaN  3.202250004
# CE 18:0;0   CE         3.736959934      8.919610023  9.816559982
# ...                            ...              ...          ...
# TAG 62:11;0 TAG                NaN              NaN            0
# TAG 62:12;0 TAG                NaN              NaN  0.875769973
# TAG 62:13;0 TAG                NaN              NaN  0.726455986
# TAG 62:14;0 TAG                NaN              NaN  1.290074021
# TAG 62:15;0 TAG                NaN              NaN            0
#
#                              73            76              89              93  \
#                   VilERT-M5B-73 VilERT-M5B-76 VilERT-G519R-89 VilERT-G519R-93
#                             iKO           iKO             iKO             iKO
# feature     class
# CE 13:0;0   CE              NaN           NaN             NaN             NaN
# CE 16:0;0   CE       70.8144989    51.5019989     21.72100067     8.547010422
# CE 16:1;0   CE      8.897470474   6.908720016             NaN             NaN
# CE 17:0;0   CE              NaN           NaN             NaN             NaN
# CE 18:0;0   CE      29.00600052   22.17180061      11.6104002     3.760890007
# ...                         ...           ...             ...             ...
# TAG 62:11;0 TAG             NaN           NaN             NaN             NaN
# TAG 62:12;0 TAG             NaN   3.564729929     21.94919968     1.870000005
# TAG 62:13;0 TAG     1.512230039   4.027210236     20.76709938     1.923650026
# TAG 62:14;0 TAG     3.734539986   4.521259785     21.57819939     2.177949905
# TAG 62:15;0 TAG             NaN           NaN     3.502039909             NaN
#
#                    ...           248           249           255  \
#                    ... Lrig1-M5B-248 Lrig1-M5B-249 Lrig1-M5B-255
#                    ...      Lrig1-D3      Lrig1-D3      Lrig1-D3
# feature     class  ...
# CE 13:0;0   CE     ...           NaN           NaN           NaN
# CE 16:0;0   CE     ...   19.11630058   15.30920029   37.17850113
# CE 16:1;0   CE     ...   2.650619984           NaN   3.167690039
# CE 17:0;0   CE     ...           NaN           NaN           NaN
# CE 18:0;0   CE     ...   6.763339996   6.528250217   11.21000004
# ...                ...           ...           ...           ...
# TAG 62:11;0 TAG    ...           NaN           NaN           NaN
# TAG 62:12;0 TAG    ...           NaN           NaN           NaN
# TAG 62:13;0 TAG    ...           NaN           NaN           NaN
# TAG 62:14;0 TAG    ...   0.690652013           NaN   1.257959962
# TAG 62:15;0 TAG    ...           NaN           NaN           NaN
#
#                             257     Lrig1-D3           Lrig-D3 vs. CON  \
#                   Lrig1-M5B-257          NaN                       NaN
#                        Lrig1-D3      Average Fold change (log, base 2)
# feature     class
# CE 13:0;0   CE              NaN            0                       NaN
# CE 16:0;0   CE      12.49040031  21.02360058                      -0.4
# CE 16:1;0   CE      2.376519918   2.73160998                      -0.7
# CE 17:0;0   CE              NaN            0                      Down
# CE 18:0;0   CE      5.821579933  7.580792546                      -0.4
# ...                         ...          ...                       ...
# TAG 62:11;0 TAG             NaN            0                       NaN
# TAG 62:12;0 TAG             NaN            0                      Down
# TAG 62:13;0 TAG             NaN            0                      Down
# TAG 62:14;0 TAG             NaN  0.974305987                      -0.4
# TAG 62:15;0 TAG             NaN            0                       NaN
#
#                   Lrig-D3 vs. CON.1          ALI        Lipid  \
#                                 NaN      H655ALI    H655Lipid
#                             P-value     DGAT-ALI   DGAT-Lipid
# feature     class
# CE 13:0;0   CE                  NaN          NaN          NaN
# CE 16:0;0   CE                 0.59  5.813129902   4.17456007
# CE 16:1;0   CE                 0.24  3.237790108  2.206110001
# CE 17:0;0   CE                  NaN          NaN          NaN
# CE 18:0;0   CE                 0.50          NaN          NaN
# ...                             ...          ...          ...
# TAG 62:11;0 TAG                 NaN          NaN          NaN
# TAG 62:12;0 TAG                 NaN          NaN          NaN
# TAG 62:13;0 TAG                 NaN          NaN  3.182519913
# TAG 62:14;0 TAG                0.66          NaN          NaN
# TAG 62:15;0 TAG                 NaN          NaN          NaN
#
#                                 Unnamed: 35
#                                        H655
#                   Fold change (log, base 2)
# feature     class
# CE 13:0;0   CE                          NaN
# CE 16:0;0   CE                         -0.5
# CE 16:1;0   CE                         -0.6
# CE 17:0;0   CE                          NaN
# CE 18:0;0   CE                          NaN
# ...                                     ...
# TAG 62:11;0 TAG                         NaN
# TAG 62:12;0 TAG                         NaN
# TAG 62:13;0 TAG                     #DIV/0!
# TAG 62:14;0 TAG                         NaN
# TAG 62:15;0 TAG                         NaN
#
# [1421 rows x 33 columns]

# %%
df_a3 = pd.read_csv('data/csv/dgat/a3_pmol.csv')

# %%
num_idx = 1
num_col_lvls=3
df_a3.iloc[num_col_lvls:, :num_idx].reset_index(drop=True)
df_a3.set_index(list(df_a3.columns[:num_idx]), inplace=True)
df_a3
# Out:
#            class structuralcategory functionalcategory  totallength  totaldb  \
# x
# NaN          NaN                NaN                NaN          NaN      NaN
# NaN          NaN                NaN                NaN          NaN      NaN
# CE 10:0;0     CE                STE                STO         10.0      0.0
# CE 11:0;0     CE                STE                STO         11.0      0.0
# CE 12:0;0     CE                STE                STO         12.0      0.0
# ...          ...                ...                ...          ...      ...
# TAG 60:5;0   TAG                 GL                STO         60.0      5.0
# TAG 60:6;0   TAG                 GL                STO         60.0      6.0
# TAG 60:7;0   TAG                 GL                STO         60.0      7.0
# TAG 60:8;0   TAG                 GL                STO         60.0      8.0
# TAG 60:9;0   TAG                 GL                STO         60.0      9.0
#
#             totaloh   fullname      aag2-C1      aag2-C2      aag2-C3  ...  \
# x                                                                      ...
# NaN             NaN  shortname       aag2C1       aag2C2       aag2C3  ...
# NaN             NaN     cohort   Aagcontrol   Aagcontrol   Aagcontrol  ...
# CE 10:0;0       0.0        NaN          NaN          NaN          NaN  ...
# CE 11:0;0       0.0        NaN          NaN          NaN          NaN  ...
# CE 12:0;0       0.0        NaN          NaN          NaN          NaN  ...
# ...             ...        ...          ...          ...          ...  ...
# TAG 60:5;0      0.0        NaN  2.043479919  2.872970104  0.953670979  ...
# TAG 60:6;0      0.0        NaN   1.76880002    2.1224401   0.81327498  ...
# TAG 60:7;0      0.0        NaN  0.960611999  1.187350035  0.570765972  ...
# TAG 60:8;0      0.0        NaN          NaN          NaN          NaN  ...
# TAG 60:9;0      0.0        NaN          NaN          NaN          NaN  ...
#
#               GPMV-V1    GPMV-V2    GPMV-V3    GPMV-V4      U2OS-C1  \
# x
# NaN            GPMVV1     GPMVV2     GPMVV3     GPMVV4       U2OSC1
# NaN         GPMVvirus  GPMVvirus  GPMVvirus  GPMVvirus  U2OScontrol
# CE 10:0;0         NaN        NaN        NaN        NaN          NaN
# CE 11:0;0         NaN        NaN        NaN        NaN          NaN
# CE 12:0;0         NaN        NaN        NaN        NaN          NaN
# ...               ...        ...        ...        ...          ...
# TAG 60:5;0        NaN        NaN        NaN        NaN  1.386270046
# TAG 60:6;0        NaN        NaN        NaN        NaN  1.170670033
# TAG 60:7;0        NaN        NaN        NaN        NaN          NaN
# TAG 60:8;0        NaN        NaN        NaN        NaN  1.286730051
# TAG 60:9;0        NaN        NaN        NaN        NaN  0.747344017
#
#                 U2OS-C2      U2OS-C3      U2OS-V1      U2OS-V2      U2OS-V3
# x
# NaN              U2OSC2       U2OSC3       U2OSV1       U2OSV2       U2OSV3
# NaN         U2OScontrol  U2OScontrol    U2OSvirus    U2OSvirus    U2OSvirus
# CE 10:0;0           NaN          NaN          NaN          NaN          NaN
# CE 11:0;0           NaN          NaN          NaN          NaN          NaN
# CE 12:0;0           NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# TAG 60:5;0  1.703940034          NaN  0.944772005  2.128760099  1.032600045
# TAG 60:6;0  1.122969985  0.906876028  1.265089989  2.175209999  1.203019977
# TAG 60:7;0  2.203739882   0.88359201   1.68919003  2.344589949   1.17990005
# TAG 60:8;0  2.046430111  1.039029956  1.650859952  2.308330059  1.382410049
# TAG 60:9;0  1.840209961  0.888028026  1.489349961  2.035140038  1.418949962
#
# [2621 rows x 39 columns]

# %%
num_col_lvls = 3
cols = [list(df_a3.columns)]
for n in range(num_col_lvls - 1):
    cols.append(list(df_a3.iloc[n]))
df_a3.columns = cols
df_a3 = df_a3[num_col_lvls - 1:]

# %%
df_a3
# Out:
#            class structuralcategory functionalcategory totallength totaldb  \
#              NaN                NaN                NaN         NaN     NaN
#              NaN                NaN                NaN         NaN     NaN
# x
# CE 10:0;0     CE                STE                STO        10.0     0.0
# CE 11:0;0     CE                STE                STO        11.0     0.0
# CE 12:0;0     CE                STE                STO        12.0     0.0
# CE 13:0;0     CE                STE                STO        13.0     0.0
# CE 14:0;0     CE                STE                STO        14.0     0.0
# ...          ...                ...                ...         ...     ...
# TAG 60:5;0   TAG                 GL                STO        60.0     5.0
# TAG 60:6;0   TAG                 GL                STO        60.0     6.0
# TAG 60:7;0   TAG                 GL                STO        60.0     7.0
# TAG 60:8;0   TAG                 GL                STO        60.0     8.0
# TAG 60:9;0   TAG                 GL                STO        60.0     9.0
#
#            totaloh  fullname      aag2-C1      aag2-C2      aag2-C3  ...  \
#                NaN shortname       aag2C1       aag2C2       aag2C3  ...
#                NaN    cohort   Aagcontrol   Aagcontrol   Aagcontrol  ...
# x                                                                    ...
# CE 10:0;0      0.0       NaN          NaN          NaN          NaN  ...
# CE 11:0;0      0.0       NaN          NaN          NaN          NaN  ...
# CE 12:0;0      0.0       NaN          NaN          NaN          NaN  ...
# CE 13:0;0      0.0       NaN          NaN          NaN  2.755389929  ...
# CE 14:0;0      0.0       NaN   11.3263998  14.41469955  26.47999954  ...
# ...            ...       ...          ...          ...          ...  ...
# TAG 60:5;0     0.0       NaN  2.043479919  2.872970104  0.953670979  ...
# TAG 60:6;0     0.0       NaN   1.76880002    2.1224401   0.81327498  ...
# TAG 60:7;0     0.0       NaN  0.960611999  1.187350035  0.570765972  ...
# TAG 60:8;0     0.0       NaN          NaN          NaN          NaN  ...
# TAG 60:9;0     0.0       NaN          NaN          NaN          NaN  ...
#
#                 GPMV-V1      GPMV-V2   GPMV-V3   GPMV-V4      U2OS-C1  \
#                  GPMVV1       GPMVV2    GPMVV3    GPMVV4       U2OSC1
#               GPMVvirus    GPMVvirus GPMVvirus GPMVvirus  U2OScontrol
# x
# CE 10:0;0           NaN          NaN       NaN       NaN          NaN
# CE 11:0;0           NaN          NaN       NaN       NaN          NaN
# CE 12:0;0           NaN          NaN       NaN       NaN          NaN
# CE 13:0;0           NaN          NaN       NaN       NaN          NaN
# CE 14:0;0   11.80360031  10.21930027       NaN       NaN  12.12950039
# ...                 ...          ...       ...       ...          ...
# TAG 60:5;0          NaN          NaN       NaN       NaN  1.386270046
# TAG 60:6;0          NaN          NaN       NaN       NaN  1.170670033
# TAG 60:7;0          NaN          NaN       NaN       NaN          NaN
# TAG 60:8;0          NaN          NaN       NaN       NaN  1.286730051
# TAG 60:9;0          NaN          NaN       NaN       NaN  0.747344017
#
#                 U2OS-C2      U2OS-C3      U2OS-V1      U2OS-V2      U2OS-V3
#                  U2OSC2       U2OSC3       U2OSV1       U2OSV2       U2OSV3
#             U2OScontrol  U2OScontrol    U2OSvirus    U2OSvirus    U2OSvirus
# x
# CE 10:0;0           NaN          NaN          NaN          NaN          NaN
# CE 11:0;0           NaN          NaN          NaN          NaN          NaN
# CE 12:0;0           NaN          NaN          NaN          NaN          NaN
# CE 13:0;0           NaN          NaN          NaN          NaN          NaN
# CE 14:0;0   21.25429916  16.40690041  17.49239922  26.64730072  26.77499962
# ...                 ...          ...          ...          ...          ...
# TAG 60:5;0  1.703940034          NaN  0.944772005  2.128760099  1.032600045
# TAG 60:6;0  1.122969985  0.906876028  1.265089989  2.175209999  1.203019977
# TAG 60:7;0  2.203739882   0.88359201   1.68919003  2.344589949   1.17990005
# TAG 60:8;0  2.046430111  1.039029956  1.650859952  2.308330059  1.382410049
# TAG 60:9;0  1.840209961  0.888028026  1.489349961  2.035140038  1.418949962
#
# [2619 rows x 39 columns]

# %%
hT = header.T
df = pd.read_csv('data/csv/dgat/a1_pmol.csv')
ds = df.set_index('feature')
dd = ds.drop(columns=list(ds.columns[:2]))

# %%
dc = dd.drop(columns = list(dd.columns[~dd.columns.isin(hT.index)]))
dc.iloc[2:].rename(columns=hT[0])
# Out:
#             VilERT-G519R-86 VilERT-G519R-94 VilERT-G519R-110 VilERT-G519R-112  \
# feature
# CE 13:0;0               NaN             NaN              NaN              NaN
# CE 16:0;0       55.57350159     30.77109909      18.34740067      10.03540039
# CE 16:1;0       7.007959843       4.1386199      2.512140036              NaN
# CE 17:0;0               NaN     3.202250004              NaN              NaN
# CE 18:0;0        18.3281002     12.43249989      5.665629864      3.736959934
# ...                     ...             ...              ...              ...
# TAG 62:11;0             NaN             NaN              NaN              NaN
# TAG 62:12;0             NaN     0.875769973              NaN              NaN
# TAG 62:13;0             NaN     0.726455986              NaN              NaN
# TAG 62:14;0      1.83307004     0.747078001              NaN              NaN
# TAG 62:15;0             NaN             NaN              NaN              NaN
#
#             VilERT-G519R-117 VilERT-M5B-73 VilERT-M5B-76 VilERT-G519R-89  \
# feature
# CE 13:0;0                NaN           NaN           NaN             NaN
# CE 16:0;0        19.29459953    70.8144989    51.5019989     21.72100067
# CE 16:1;0                NaN   8.897470474   6.908720016             NaN
# CE 17:0;0                NaN           NaN           NaN             NaN
# CE 18:0;0        8.919610023   29.00600052   22.17180061      11.6104002
# ...                      ...           ...           ...             ...
# TAG 62:11;0              NaN           NaN           NaN             NaN
# TAG 62:12;0              NaN           NaN   3.564729929     21.94919968
# TAG 62:13;0              NaN   1.512230039   4.027210236     20.76709938
# TAG 62:14;0              NaN   3.734539986   4.521259785     21.57819939
# TAG 62:15;0              NaN           NaN           NaN     3.502039909
#
#             VilERT-G519R-93 Lrig-M5B-195  ... VilERT-G519R-80 VilERT-G519R-83  \
# feature                                   ...
# CE 13:0;0               NaN          NaN  ...             NaN             NaN
# CE 16:0;0       8.547010422  47.35210037  ...             NaN             NaN
# CE 16:1;0               NaN  5.783070087  ...             NaN             NaN
# CE 17:0;0               NaN          NaN  ...             NaN             NaN
# CE 18:0;0       3.760890007  18.20269966  ...             NaN             NaN
# ...                     ...          ...  ...             ...             ...
# TAG 62:11;0             NaN          NaN  ...             NaN             NaN
# TAG 62:12;0     1.870000005          NaN  ...      1.52489996             NaN
# TAG 62:13;0     1.923650026  0.854660988  ...             NaN             NaN
# TAG 62:14;0     2.177949905  1.490090013  ...     4.555309772     1.582180023
# TAG 62:15;0             NaN          NaN  ...             NaN             NaN
#
#             VilERT-G519R-108 VilERT-G519R-116 Lrig1-M5B-248 Lrig1-M5B-249  \
# feature
# CE 13:0;0                NaN      4.519790173           NaN           NaN
# CE 16:0;0                NaN      4.310719967   19.11630058   15.30920029
# CE 16:1;0                NaN              NaN   2.650619984           NaN
# CE 17:0;0                NaN              NaN           NaN           NaN
# CE 18:0;0                NaN      5.167620182   6.763339996   6.528250217
# ...                      ...              ...           ...           ...
# TAG 62:11;0              NaN      0.736540973           NaN           NaN
# TAG 62:12;0      2.081429958      3.064599991           NaN           NaN
# TAG 62:13;0       2.38222003      2.810830116           NaN           NaN
# TAG 62:14;0      2.348210096      3.198800087   0.690652013           NaN
# TAG 62:15;0              NaN              NaN           NaN           NaN
#
#             Lrig1-M5B-255 Lrig1-M5B-257      H655ALI    H655Lipid
# feature
# CE 13:0;0             NaN           NaN          NaN          NaN
# CE 16:0;0     37.17850113   12.49040031  5.813129902   4.17456007
# CE 16:1;0     3.167690039   2.376519918  3.237790108  2.206110001
# CE 17:0;0             NaN           NaN          NaN          NaN
# CE 18:0;0     11.21000004   5.821579933          NaN          NaN
# ...                   ...           ...          ...          ...
# TAG 62:11;0           NaN           NaN          NaN          NaN
# TAG 62:12;0           NaN           NaN          NaN          NaN
# TAG 62:13;0           NaN           NaN          NaN  3.182519913
# TAG 62:14;0   1.257959962           NaN          NaN          NaN
# TAG 62:15;0           NaN           NaN          NaN          NaN
#
# [1421 rows x 22 columns]

# %%
dfc = df.drop(columns=df.columns[:3])
dfc[:3-1].T
# Out:
#                                   0                          1
# 86                  VilERT-G519R-86                    Control
# 94                  VilERT-G519R-94                    Control
# 110                VilERT-G519R-110                    Control
# 112                VilERT-G519R-112                    Control
# 117                VilERT-G519R-117                    Control
# Control                         NaN                    Average
# 73                    VilERT-M5B-73                        iKO
# 76                    VilERT-M5B-76                        iKO
# 89                  VilERT-G519R-89                        iKO
# 93                  VilERT-G519R-93                        iKO
# 195                    Lrig-M5B-195                        iKO
# 196                    Lrig-M5B-196                        iKO
# iKO                             NaN                    Average
# iKO vs. CON                     NaN  Fold change (log, base 2)
# iKO vs. CON.1                   NaN                    P-value
# 63                  VilERT-G519R-63                      G519R
# 80                  VilERT-G519R-80                      G519R
# 83                  VilERT-G519R-83                      G519R
# 108                VilERT-G519R-108                      G519R
# 116                VilERT-G519R-116                      G519R
# G519R                           NaN                    Average
# G519R vs. CON                   NaN  Fold change (log, base 2)
# G519R vs. CON.1                 NaN                    P-value
# 248                   Lrig1-M5B-248                   Lrig1-D3
# 249                   Lrig1-M5B-249                   Lrig1-D3
# 255                   Lrig1-M5B-255                   Lrig1-D3
# 257                   Lrig1-M5B-257                   Lrig1-D3
# Lrig1-D3                        NaN                    Average
# Lrig-D3 vs. CON                 NaN  Fold change (log, base 2)
# Lrig-D3 vs. CON.1               NaN                    P-value
# ALI                         H655ALI                   DGAT-ALI
# Lipid                     H655Lipid                 DGAT-Lipid
# Unnamed: 35                    H655  Fold change (log, base 2)
